# %%
conversation_example_1 = """
Customer: Hi, I ordered a laptop from your store last week, but I received the wrong color.

Agent: I apologize for this mistake. Could you please provide your order number?

Customer: Sure, it's #ORDER45678

Agent: Thank you. I can see the error in our system. I can arrange for a replacement in your preferred color, and we'll send you a prepaid return label for the current laptop. Also, I'll add a 10% discount on your next purchase as compensation for the inconvenience.

Customer: That's really great! Thank you so much for handling this so quickly. I appreciate the discount too!

Agent: You're welcome! The return label will be emailed to you within the next hour, and your replacement laptop will ship tomorrow with priority delivery.

Customer: Perfect! Have a great day! 
"""


conversation_example_2 = """
Customer: This is the third time I'm contacting you about my broken washing machine. No one has shown up for the repair despite scheduling 3 appointments!

Agent: I can see your previous contacts. Could you please provide your reference number again?

Customer: Are you kidding me? I've given that number THREE times already! It's WR789012. This is absolutely ridiculous.

Agent: I understand your frustration. Let me check the status.

Customer: I've been waiting for 20 minutes now. I'm paying for a premium warranty and this is the service I get? I want to speak to a supervisor immediately.

Agent: I apologize, but all our supervisors are currently unavailable. I can have one call you back within 24 hours.

Customer: This is unacceptable! I'm going to post about this terrible service on social media and file a formal complaint. You've wasted my time and money. I'll never buy from your company again.

Agent: I apologize for your experience. I'll escalate this case...

Customer: Don't bother. I'm done with this company. 
"""

# %%
sentiment_eval_prompt = """
Analyze the sentiment of the following conversation and classify it as either "positive" "negative" "neutral" or "mixed" 

Analyze the conversation below and provide the sentiment analysis in JSON format with two fields:
- sentiment: (positive/negative/neutral/mixed)
- reason: (detailed explanation for the classification)

<conversation>
{{conversation}}
</conversation>

Response:
{
    "sentiment": "",
    "reason": ""
}
"""

# %%
import boto3
import json

def bedrock_chat(prompt, system_prompt, model_id):
    client = boto3.client("bedrock-runtime")

    system = [{"text": system_prompt}]
    messages = [{"role": "user", "content": [{"text": prompt}]}]
    
    inf_params = {
        "maxTokens": 2048,
        "topP": 0.1,
        "temperature": 0.3
    }

    additionalModelRequestFields = {
        "inferenceConfig": {"topK": 20}
    }

    model_response = client.converse(
        modelId=model_id,
        messages=messages,
        system=system,
        inferenceConfig=inf_params,
        additionalModelRequestFields=additionalModelRequestFields
    )

    return model_response["output"]["message"]["content"][0]["text"]

def prepare_prompt(template, **kwargs):
    for key, value in kwargs.items():
        template = template.replace(f"{{{{{key}}}}}", value)
    return template

# %%
# Example usage
conversation_examples = [
    conversation_example_1,
    conversation_example_2
]

ground_truths = [
    {
        "sentiment": "positive",
    },
    {
        "sentiment": "negative",
    }
]

# %%
def evaluate_conversation(conversation_examples, current_prompt):
    results = []
    
    for conversation in conversation_examples:
        sentiment_prompt = prepare_prompt(current_prompt, conversation=conversation)
        system_prompt_evaluation = "You are a helpful assistant. Always respond with clean JSON format without markdown or escape characters."
        model_id = "us.amazon.nova-pro-v1:0"
        sentiment_response = bedrock_chat(sentiment_prompt,system_prompt_evaluation,model_id)
        
        try:
            result = json.loads(sentiment_response)
            results.append(result)
        except json.JSONDecodeError:
            results.append({
                "error": "Failed to parse API response",
                "sentiment_raw": sentiment_response
            })
    
    return results

# %%
evaluation_llm = evaluate_conversation(conversation_examples,sentiment_eval_prompt)

# %%
def evaluate_with_ground_truth(model_outputs, ground_truths):
    combined_results = []
    correct_predictions = 0
    total_predictions = len(ground_truths)
    
    for model_output, ground_truth in zip(model_outputs, ground_truths):
        sentiment_match = model_output.get("sentiment", "").lower() == ground_truth.get("sentiment", "").lower()
        if sentiment_match:
            correct_predictions += 1
        
        result = {
            "model_sentiment": model_output.get("sentiment", "").lower(),
            "model_reasoning": model_output.get("reason", ""),
            "ground_truth_sentiment": ground_truth.get("sentiment", "").lower(),
            "is_correct": sentiment_match
        }
        
        combined_results.append(result)
    
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    
    return {
        "accuracy": round(accuracy, 2),
        "correct_predictions": correct_predictions,
        "total_predictions": total_predictions,
        "detailed_results": combined_results
    }

# %%
evaluation_results = evaluate_with_ground_truth(evaluation_llm, ground_truths)

# %%
evaluation_results
# Out:
# {'accuracy': 1.0,
#  'correct_predictions': 2,
#  'total_predictions': 2,
#  'detailed_results': [{'model_sentiment': 'positive',
#    'model_reasoning': 'The conversation starts with a customer complaint about receiving the wrong color laptop. However, the agent responds promptly with an apology, requests the order number, and takes immediate action to resolve the issue by arranging a replacement and offering a discount. The customer expresses appreciation for the quick resolution and the compensation. The agent confirms the actions to be taken and ensures the customer that the issue will be resolved promptly. Overall, the interaction ends on a positive note with both parties satisfied.',
#    'ground_truth_sentiment': 'positive',
#    'is_correct': True},
#   {'model_sentiment': 'negative',
#    'model_reasoning': "The conversation is predominantly negative. The customer expresses strong dissatisfaction and frustration multiple times, mentioning repeated failed appointments, the need to provide the same reference number multiple times, and the lack of timely resolution. The customer also threatens to post about the poor service on social media, file a formal complaint, and states they will never buy from the company again. The agent's responses, while attempting to be helpful, do not alleviate the customer's anger, contributing to the overall negative sentiment.",
#    'ground_truth_sentiment': 'negative',
#    'is_correct': True}]}

# %%
critique_prompt_template = """
Analyze the classification performance and provide detailed reasoning for prompt improvements:

Current Template:
{{input_current_template}}

Evaluation Results:
{{evaluation_results}}

Follow these steps in order:

1. STEP 1 - Error Pattern Analysis:
   - List each misclassified case
   - Group similar errors
   - Focus on how the prompt's instructions led to these errors
   YOUR ANALYSIS:

2. STEP 2 - Prompt-Specific Root Cause Investigation:
   For each error pattern identified above, analyze:
   - Which parts of the current prompt led to misinterpretation?
   - Are there ambiguous or missing instructions?
   - Are the classification criteria clearly defined?
   - Is the format/structure of the prompt causing confusion?
   YOUR ANALYSIS:

3. STEP 3 - Historical Context:
   Previous Suggestions: {{suggestion_history}}
   Analyze only prompt-related changes:
   - Which prompt modifications were effective/ineffective?
   - Which instruction clarity issues persist?
   - What prompt elements still need refinement?
   YOUR ANALYSIS:

4. STEP 4 - Prompt Improvement Ideas:
   Suggest only changes to prompt instructions and structure:
   - Clearer classification criteria
   - Better examples or explanations
   - More precise instructions
   - Better prompt structure or organization
   - Specific wording improvements
   
   AVOID suggesting:
   Adding more training data
   Modifying the model
   Changes to the underlying AI system
   Adding new model capabilities
   
   YOUR IDEAS:

Remember: Focus solely on how to improve the prompt instructions, format, and clarity. All suggestions must be implementable through prompt engineering alone.
"""

# %%
format_prompt = """
Based on the analysis below, structure the recommendations in the following format and create a new improved template:

Current Template:
{{input_current_template}}

Analysis:
{{critique_feedbacks}}

Instructions for improved template:
1. Take the current template as a base
2. Apply the high-priority recommendations to create a new template
3. Incorporate specific improvements identified in the analysis
4. Ensure the new template maintains the basic structure but addresses the identified issues
5. The improved template should be a complete, ready-to-use prompt

Return your response in this exact JSON format:
{
    "analysis": {
        "error_patterns": [
            "List specific error patterns found"
        ],
        "root_causes": [
            "List root causes of errors"
        ]
    },
    "recommendations": {
        "high_priority": [
            "List specific changes that should be made immediately"
        ],
        "medium_priority": [
            "List important but not critical changes"
        ],
        "low_priority": [
            "List minor optimization suggestions"
        ]
    },
    "improved_template": "Provide the complete new template here with all recommended changes incorporated. This should be a fully functional template ready for the next iteration."
}

IMPORTANT: The improved_template must be different from the current template and incorporate the recommended changes. Do not simply return the original template.
"""

# %%
def critique_performance(critique_prompt_template, current_prompt, eval_results, feedback_history):
    """
    Analyze classification performance and generate critique
    
    Args:
        current_prompt (str): Current prompt template
        eval_results (dict): Evaluation results including accuracy and detailed results
        feedback_history (list): History of previous feedback and optimizations
    
    Returns:
        dict: Analysis results including error patterns and root causes
    """
    analysis_prompt = prepare_prompt(
        critique_prompt_template,
        input_current_template=current_prompt,
        evaluation_results=json.dumps(eval_results, indent=2),
        suggestion_history=json.dumps(feedback_history, indent=2)
    )
    
    system_prompt = "You are a helpful assistant focused on detailed analysis. Follow the steps carefully."
    model_id = "us.amazon.nova-pro-v1:0"
    analysis_response = bedrock_chat(analysis_prompt, system_prompt, model_id)
    return analysis_response

# %%
def optimize_prompt(format_prompt, current_prompt, critique_feedback):
    """
    Generate optimized prompt based on critique results
    
    Args:
        format_prompt (str): Template for formatting optimization output
        current_prompt (str): Current prompt template
        critique_feedback (str): Detailed analysis from critique_performance function
    
    Returns:
        dict: Structured optimization results including analysis and recommendations
    """
    optimization_prompt = prepare_prompt(
        format_prompt,
        input_current_template=current_prompt,
        critique_feedbacks=critique_feedback
    )
    
    system_prompt = "You are a helpful assistant. Always respond with clean JSON format without markdown or escape characters."
    model_id = "us.amazon.nova-pro-v1:0"
    optimization_response = bedrock_chat(optimization_prompt, system_prompt, model_id)
    
    try:
        optimization = json.loads(optimization_response)
        return optimization
    except json.JSONDecodeError:
        return {
            "error": "Failed to parse optimization response",
            "raw_response": optimization_response
        }

# %%
def run_feedback_loop(conversation_examples, ground_truths, iterations=3):
    current_prompt = sentiment_eval_prompt
    feedback_history = []
    accuracy_history = []
    
    for i in range(iterations):        
        print(f"\nIteration {i+1}")
        print("="*50)
        
        # Get model predictions and evaluate
        print("Current Prompt ######")
        print(current_prompt)
        predictions = evaluate_conversation(conversation_examples, current_prompt)
        eval_results = evaluate_with_ground_truth(predictions, ground_truths)
        
        # Track accuracy
        current_accuracy = eval_results["accuracy"]
        accuracy_history.append(current_accuracy)
        
        print(f"Accuracy: {current_accuracy*100:.2f}%")
        print(f"Correct: {eval_results['correct_predictions']}/{eval_results['total_predictions']}")
        
        # Show detailed results
        for idx, result in enumerate(eval_results["detailed_results"]):
            print(f"\nConversation {idx + 1}:")
            print(f"Predicted: {result['model_sentiment']}")
            print(f"Actual: {result['ground_truth_sentiment']}")
            print(f"Correct: {'✓' if result['is_correct'] else '✗'}")
        
        # Get critique and optimization
        critique_feedback = critique_performance(
            critique_prompt_template, 
            current_prompt, 
            eval_results, 
            feedback_history
        )

        print("FEEDBACK FROM CRITIQUE LLM ######")
        print(critique_feedback)
        
        optimization_results = optimize_prompt(
            format_prompt,
            current_prompt,
            critique_feedback
        )

        print("IMPROVED OPTIMIZATION ######")
        print(optimization_results)

        # Store feedback
        feedback_history.append({
            "iteration": i + 1,
            "current_prompt": current_prompt,
            "critique_feedback": critique_feedback,
            "optimization_results": optimization_results,
            "accuracy": current_accuracy
        })

        # Update prompt for next iteration
        if isinstance(optimization_results, dict) and "improved_template" in optimization_results:
            current_prompt = optimization_results["improved_template"]


    return {
        "final_prompt": current_prompt,
        "feedback_history": feedback_history,
        "accuracy_history": accuracy_history,
        "final_accuracy": accuracy_history[-1] if accuracy_history else 0
    }

# %%
conversation_examples = [
    # Conversation 1: Sarcastic positive words but negative sentiment
    """
    Customer: Oh 'wonderful', another delayed delivery. Just 'perfect'!
    Agent: I apologize for the delay. I can check the status for you.
    Customer: That would be just 'fantastic', like the last three times I contacted support.
    Agent: I understand your frustration. Let me expedite this for you.
    Customer: Thanks SO much for your 'amazing' service! You're really 'exceptional' at this!
    """,
    
    # Conversation 2: Mixed signals with subtle final sentiment
    """
    Customer: My order arrived damaged, but your delivery was quick.
    Agent: I'm sorry about the damage. We'll send a replacement immediately.
    Customer: I appreciate the fast response, though this is the second time it happened.
    Agent: We'll add extra packaging protection and include a small gift for the inconvenience.
    Customer: Well, at least you're trying to improve. We'll see how it goes.
    """,
    
    # Conversation 3: Polite words masking negative sentiment
    """
    Customer: I hate to bother you, but this is my fourth attempt to resolve this issue.
    Agent: I'll be happy to help you today.
    Customer: Thank you, I know it's not your fault personally, but I've spent hours on this.
    Agent: I understand, let me review your case history.
    Customer: I appreciate your time, but I might need to explore other options if this continues.
    """,
    
    # Conversation 4: Complex emotional progression
    """
    Customer: This product is completely useless! I want a refund!
    Agent: I sincerely apologize. I can process your refund and offer a 30% discount on your next purchase.
    Customer: I don't want discounts, I've wasted enough money already!
    Agent: I understand. What if I send you our premium version as a replacement at no cost?
    Customer: Hmm... well, I've heard good things about that model. Fine, I'll give it a try.
    Agent: Excellent! I'll expedite that shipping for you.
    Customer: Thanks, I guess. But it better work this time.
    """
]

ground_truths = [
    {
        "sentiment": "negative"
    },
    {
        "sentiment": "neutral"
    },
    {
        "sentiment": "negative"
    },
    {
        "sentiment": "mixed"
    }
]

# %%
# Usage
results = run_feedback_loop(conversation_examples, ground_truths, iterations=5)
# Out:
# Iteration 1
# ==================================================
# Current Prompt ######
#
# Analyze the sentiment of the following conversation and classify it as either "positive" "negative" "neutral" or "mixed"
#
# Analyze the conversation below and provide the sentiment analysis in JSON format with two fields:
# - sentiment: (positive/negative/neutral/mixed)
# - reason: (detailed explanation for the classification)
#
# <conversation>
# {{conversation}}
# </conversation>
#
# Response:
# {
#     "sentiment": "",
#     "reason": ""
# }
#
# Accuracy: 50.00%
# Correct: 2/4
#
# Conversation 1:
# Predicted: negative
# Actual: negative
# Correct: ✓
#
# Conversation 2:
# Predicted: mixed
# Actual: neutral
# Correct: ✗
#
# Conversation 3:
# Predicted: mixed
# Actual: negative
# Correct: ✗
#
# Conversation 4:
# Predicted: mixed
# Actual: mixed
# Correct: ✓
# FEEDBACK FROM CRITIQUE LLM ######
# ### STEP 1 - Error Pattern Analysis:
#
# **Misclassified Cases:**
# 1. **Case 2:**
#    - **Model Sentiment:** Mixed
#    - **Ground Truth Sentiment:** Neutral
#    - **Reasoning:** The model identified both positive and negative elements, leading to a "mixed" classification, whereas the ground truth was "neutral."
#
# 2. **Case 3:**
#    - **Model Sentiment:** Mixed
#    - **Ground Truth Sentiment:** Negative
#    - **Reasoning:** The model identified both negative and positive elements, leading to a "mixed" classification, whereas the ground truth was "negative."
#
# **Grouped Error Patterns:**
# - **Pattern 1:** Misclassification due to the presence of both positive and negative elements, leading to "mixed" when the ground truth is either "neutral" or "negative."
#
# ### STEP 2 - Prompt-Specific Root Cause Investigation:
#
# **Case 2 Analysis:**
# - **Misinterpretation:** The model seems to have overemphasized the positive elements (quick delivery, accommodating agent) and underemphasized the overall neutral tone of the conversation.
# - **Ambiguous Instructions:** The prompt does not clearly define what constitutes a "mixed" sentiment versus a "neutral" sentiment.
# - **Classification Criteria:** The criteria for "mixed" sentiment may be too broad, causing the model to incorrectly classify conversations that are essentially neutral but contain some positive and negative elements.
#
# **Case 3 Analysis:**
# - **Misinterpretation:** The model identified both negative and positive elements, leading to a "mixed" classification, but the overall tone of the conversation was more negative.
# - **Ambiguous Instructions:** Similar to Case 2, the prompt lacks clear differentiation between "mixed" and "negative" sentiments.
# - **Classification Criteria:** The model may be misinterpreting the balance of positive and negative elements, leading to an incorrect "mixed" classification when the conversation is predominantly negative.
#
# ### STEP 3 - Historical Context:
#
# **Previous Suggestions:**
# - None provided, so we will focus on the current issues.
#
# **Analysis of Current Issues:**
# - **Effective Modifications:** None identified, as this is the first evaluation.
# - **Persisting Issues:**
#   - Ambiguity in classification criteria, particularly for "mixed" versus "neutral" and "mixed" versus "negative."
#   - Lack of clear examples or explanations for each sentiment category.
#
# ### STEP 4 - Prompt Improvement Ideas:
#
# **Clearer Classification Criteria:**
# - Provide explicit definitions for each sentiment category.
#   - **Neutral:** Conversations that lack strong positive or negative emotions.
#   - **Mixed:** Conversations that contain a balanced amount of both positive and negative sentiments.
#   - **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements.
#   - **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements.
#
# **Better Examples or Explanations:**
# - Include example conversations for each sentiment category to illustrate the differences.
#   - **Neutral Example:** "I received my order today. It was neither good nor bad."
#   - **Mixed Example:** "The product was great, but the delivery was late."
#   - **Negative Example:** "I hate this product and will never buy from you again."
#   - **Positive Example:** "This is the best service I’ve ever received!"
#
# **More Precise Instructions:**
# - Clarify that "mixed" should only be used when there is a clear and balanced presence of both positive and negative sentiments.
# - Emphasize that "neutral" should be used for conversations that do not strongly lean towards either positive or negative.
#
# **Better Prompt Structure or Organization:**
# - Organize the prompt to first define the sentiment categories, then provide examples, and finally ask for the classification.
#
# **Specific Wording Improvements:**
# - Use more definitive language to avoid ambiguity.
#
# ### Improved Prompt:
#
# ```
# Analyze the sentiment of the following conversation and classify it as either "positive", "negative", "neutral", or "mixed".
#
# **Sentiment Definitions:**
# - **Neutral:** Conversations that lack strong positive or negative emotions.
# - **Mixed:** Conversations that contain a balanced amount of both positive and negative sentiments.
# - **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements.
# - **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements.
#
# **Examples:**
# - **Neutral:** "I received my order today. It was neither good nor bad."
# - **Mixed:** "The product was great, but the delivery was late."
# - **Negative:** "I hate this product and will never buy from you again."
# - **Positive:** "This is the best service I’ve ever received!"
#
# Analyze the conversation below and provide the sentiment analysis in JSON format with two fields:
# - sentiment: (positive/negative/neutral/mixed)
# - reason: (detailed explanation for the classification)
#
# <conversation>
# {{conversation}}
# </conversation>
#
# Response:
# {
#     "sentiment": "",
#     "reason": ""
# }
# ```
# IMPROVED OPTIMIZATION ######
# {'analysis': {'error_patterns': ["Misclassification due to the presence of both positive and negative elements, leading to 'mixed' when the ground truth is either 'neutral' or 'negative.'"], 'root_causes': ["Ambiguous instructions for differentiating between 'mixed' and 'neutral' or 'negative' sentiments.", 'Lack of clear examples or explanations for each sentiment category.', 'Misinterpretation of the balance of positive and negative elements.']}, 'recommendations': {'high_priority': ['Provide explicit definitions for each sentiment category.', 'Include example conversations for each sentiment category to illustrate the differences.', "Clarify that 'mixed' should only be used when there is a clear and balanced presence of both positive and negative sentiments.", "Emphasize that 'neutral' should be used for conversations that do not strongly lean towards either positive or negative."], 'medium_priority': ['Organize the prompt to first define the sentiment categories, then provide examples, and finally ask for the classification.', 'Use more definitive language to avoid ambiguity.'], 'low_priority': ['Consider adding more examples for each sentiment category to further clarify the distinctions.']}, 'improved_template': 'Analyze the sentiment of the following conversation and classify it as either \'positive\', \'negative\', \'neutral\', or \'mixed\'.\n\n**Sentiment Definitions:**\n- **Neutral:** Conversations that lack strong positive or negative emotions.\n- **Mixed:** Conversations that contain a balanced amount of both positive and negative sentiments.\n- **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements.\n- **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements.\n\n**Examples:**\n- **Neutral:** \'I received my order today. It was neither good nor bad.\'\n- **Mixed:** \'The product was great, but the delivery was late.\'\n- **Negative:** \'I hate this product and will never buy from you again.\'\n- **Positive:** \'This is the best service I’ve ever received!\'\n\n**Instructions:**\n- Ensure that \'mixed\' is only used for conversations with a clear and balanced presence of both positive and negative sentiments.\n- Use \'neutral\' for conversations that do not strongly lean towards either positive or negative.\n\nAnalyze the conversation below and provide the sentiment analysis in JSON format with two fields:\n- sentiment: (positive/negative/neutral/mixed)\n- reason: (detailed explanation for the classification)\n\n<conversation>\n{{conversation}}\n</conversation>\n\nResponse:\n{\n    "sentiment": "",\n    "reason": ""\n}'}
#
# Iteration 2
# ==================================================
# Current Prompt ######
# Analyze the sentiment of the following conversation and classify it as either 'positive', 'negative', 'neutral', or 'mixed'.
#
# **Sentiment Definitions:**
# - **Neutral:** Conversations that lack strong positive or negative emotions.
# - **Mixed:** Conversations that contain a balanced amount of both positive and negative sentiments.
# - **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements.
# - **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements.
#
# **Examples:**
# - **Neutral:** 'I received my order today. It was neither good nor bad.'
# - **Mixed:** 'The product was great, but the delivery was late.'
# - **Negative:** 'I hate this product and will never buy from you again.'
# - **Positive:** 'This is the best service I’ve ever received!'
#
# **Instructions:**
# - Ensure that 'mixed' is only used for conversations with a clear and balanced presence of both positive and negative sentiments.
# - Use 'neutral' for conversations that do not strongly lean towards either positive or negative.
#
# Analyze the conversation below and provide the sentiment analysis in JSON format with two fields:
# - sentiment: (positive/negative/neutral/mixed)
# - reason: (detailed explanation for the classification)
#
# <conversation>
# {{conversation}}
# </conversation>
#
# Response:
# {
#     "sentiment": "",
#     "reason": ""
# }
# Accuracy: 75.00%
# Correct: 3/4
#
# Conversation 1:
# Predicted: negative
# Actual: negative
# Correct: ✓
#
# Conversation 2:
# Predicted: mixed
# Actual: neutral
# Correct: ✗
#
# Conversation 3:
# Predicted: negative
# Actual: negative
# Correct: ✓
#
# Conversation 4:
# Predicted: mixed
# Actual: mixed
# Correct: ✓
# FEEDBACK FROM CRITIQUE LLM ######
# ### STEP 1 - Error Pattern Analysis:
# - **Misclassified Case:**
#   - **Case 2:**
#     - **Model Sentiment:** Mixed
#     - **Ground Truth Sentiment:** Neutral
#     - **Reasoning:** The model identified both positive and negative elements, leading to a "mixed" classification, whereas the ground truth was "neutral."
#
# ### STEP 2 - Prompt-Specific Root Cause Investigation:
# - **Case 2 Analysis:**
#   - **Misinterpretation:** The model seems to have overemphasized the positive elements (quick delivery, accommodating agent) and underemphasized the overall neutral tone of the conversation.
#   - **Ambiguous Instructions:** The prompt does not clearly define what constitutes a "mixed" sentiment versus a "neutral" sentiment.
#   - **Classification Criteria:** The criteria for "mixed" sentiment may be too broad, causing the model to incorrectly classify conversations that are essentially neutral but contain some positive and negative elements.
#
# ### STEP 3 - Historical Context:
# - **Previous Suggestions Analysis:**
#   - The previous iteration introduced clearer classification criteria, better examples, and more precise instructions. However, the accuracy only improved to 0.75, indicating that some issues persist.
#   - **Persisting Issues:**
#     - Ambiguity in classification criteria, particularly for "mixed" versus "neutral."
#     - Potential misinterpretation of the balance of positive and negative elements.
#
# ### STEP 4 - Prompt Improvement Ideas:
# To further refine the prompt and address the remaining issues, the following improvements are suggested:
#
# #### Clearer Classification Criteria:
# - **Enhanced Definitions:**
#   ```markdown
#   **Sentiment Definitions:**
#   - **Neutral:** Conversations that lack strong positive or negative emotions. These conversations may mention both positive and negative aspects, but neither sentiment dominates.
#   - **Mixed:** Conversations that contain a clear and balanced amount of both positive and negative sentiments. The positive and negative elements should be roughly equal in weight and significance.
#   - **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements. The negative aspects should significantly outweigh any positive remarks.
#   - **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements. The positive aspects should significantly outweigh any negative remarks.
#   ```
#
# #### Better Examples or Explanations:
# - **Additional Examples:**
#   ```markdown
#   **Examples:**
#   - **Neutral:**
#     - "I received my order today. It was neither good nor bad."
#     - "The service was okay, nothing special but also not bad."
#   - **Mixed:**
#     - "The product was great, but the delivery was late."
#     - "I love the features of this app, but the customer support is terrible."
#   - **Negative:**
#     - "I hate this product and will never buy from you again."
#     - "The service was horrible and I’m extremely disappointed."
#   - **Positive:**
#     - "This is the best service I’ve ever received!"
#     - "I’m very satisfied with the product and the quick delivery."
#   ```
#
# #### More Precise Instructions:
# - **Clarified Instructions:**
#   ```markdown
#   **Instructions:**
#   - Ensure that 'mixed' is only used for conversations with a clear and balanced presence of both positive and negative sentiments. The positive and negative elements should be of similar weight and significance.
#   - Use 'neutral' for conversations that do not strongly lean towards either positive or negative. Even if there are some positive and negative mentions, if neither sentiment dominates, classify it as 'neutral'.
#   - For 'negative', the conversation should predominantly convey negative emotions, despite any positive remarks.
#   - For 'positive', the conversation should predominantly convey positive emotions, despite any negative remarks.
#   ```
#
# #### Better Prompt Structure or Organization:
# - **Organized Prompt:**
#   ```markdown
#   Analyze the sentiment of the following conversation and classify it as either 'positive', 'negative', 'neutral', or 'mixed'.
#
#   **Sentiment Definitions:**
#   - **Neutral:** Conversations that lack strong positive or negative emotions. These conversations may mention both positive and negative aspects, but neither sentiment dominates.
#   - **Mixed:** Conversations that contain a clear and balanced amount of both positive and negative sentiments. The positive and negative elements should be roughly equal in weight and significance.
#   - **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements. The negative aspects should significantly outweigh any positive remarks.
#   - **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements. The positive aspects should significantly outweigh any negative remarks.
#
#   **Examples:**
#   - **Neutral:**
#     - "I received my order today. It was neither good nor bad."
#     - "The service was okay, nothing special but also not bad."
#   - **Mixed:**
#     - "The product was great, but the delivery was late."
#     - "I love the features of this app, but the customer support is terrible."
#   - **Negative:**
#     - "I hate this product and will never buy from you again."
#     - "The service was horrible and I’m extremely disappointed."
#   - **Positive:**
#     - "This is the best service I’ve ever received!"
#     - "I’m very satisfied with the product and the quick delivery."
#
#   **Instructions:**
#   - Ensure that 'mixed' is only used for conversations with a clear and balanced presence of both positive and negative sentiments. The positive and negative elements should be of similar weight and significance.
#   - Use 'neutral' for conversations that do not strongly lean towards either positive or negative. Even if there are some positive and negative mentions, if neither sentiment dominates, classify it as 'neutral'.
#   - For 'negative', the conversation should predominantly convey negative emotions, despite any positive remarks.
#   - For 'positive', the conversation should predominantly convey positive emotions, despite any negative remarks.
#
#   Analyze the conversation below and provide the sentiment analysis in JSON format with two fields:
#   - sentiment: (positive/negative/neutral/mixed)
#   - reason: (detailed explanation for the classification)
#
#   <conversation>
#   {{conversation}}
#   </conversation>
#
#   Response:
#   {
#       "sentiment": "",
#       "reason": ""
#   }
#   ```
#
# ### Summary of Improvements:
# - **Enhanced Definitions:** Provided more detailed and specific definitions for each sentiment category.
# - **Additional Examples:** Included more examples to illustrate the differences between neutral and mixed sentiments.
# - **Clarified Instructions:** Emphasized the need for a clear and balanced presence of both positive and negative elements for "mixed" classification and reinforced the criteria for "neutral."
# - **Organized Prompt:** Structured the prompt to first define the sentiment categories, then provide examples, and finally ask for the classification.
# IMPROVED OPTIMIZATION ######
# {'analysis': {'error_patterns': ["Misclassified case where 'mixed' was incorrectly assigned instead of 'neutral'."], 'root_causes': ["Ambiguous instructions for distinguishing between 'mixed' and 'neutral' sentiments.", "Overemphasis on positive elements leading to incorrect 'mixed' classification.", 'Broad classification criteria causing misinterpretation of sentiment balance.']}, 'recommendations': {'high_priority': ['Enhance definitions for each sentiment category to provide clearer distinctions.', "Include additional examples to illustrate the differences between 'neutral' and 'mixed' sentiments.", "Clarify instructions to emphasize the need for a clear and balanced presence of both positive and negative elements for 'mixed' classification."], 'medium_priority': ['Reorganize the prompt to first define sentiment categories, then provide examples, and finally ask for classification.'], 'low_priority': ['Consider adding more diverse examples to cover a wider range of scenarios.']}, 'improved_template': 'Analyze the sentiment of the following conversation and classify it as either \'positive\', \'negative\', \'neutral\', or \'mixed\'.\n\n**Sentiment Definitions:**\n- **Neutral:** Conversations that lack strong positive or negative emotions. These conversations may mention both positive and negative aspects, but neither sentiment dominates.\n- **Mixed:** Conversations that contain a clear and balanced amount of both positive and negative sentiments. The positive and negative elements should be roughly equal in weight and significance.\n- **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements. The negative aspects should significantly outweigh any positive remarks.\n- **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements. The positive aspects should significantly outweigh any negative remarks.\n\n**Examples:**\n- **Neutral:** \n  - "I received my order today. It was neither good nor bad."\n  - "The service was okay, nothing special but also not bad."\n- **Mixed:** \n  - "The product was great, but the delivery was late."\n  - "I love the features of this app, but the customer support is terrible."\n- **Negative:** \n  - "I hate this product and will never buy from you again."\n  - "The service was horrible and I’m extremely disappointed."\n- **Positive:** \n  - "This is the best service I’ve ever received!"\n  - "I’m very satisfied with the product and the quick delivery."\n\n**Instructions:**\n- Ensure that \'mixed\' is only used for conversations with a clear and balanced presence of both positive and negative sentiments. The positive and negative elements should be of similar weight and significance.\n- Use \'neutral\' for conversations that do not strongly lean towards either positive or negative. Even if there are some positive and negative mentions, if neither sentiment dominates, classify it as \'neutral\'.\n- For \'negative\', the conversation should predominantly convey negative emotions, despite any positive remarks.\n- For \'positive\', the conversation should predominantly convey positive emotions, despite any negative remarks.\n\nAnalyze the conversation below and provide the sentiment analysis in JSON format with two fields:\n- sentiment: (positive/negative/neutral/mixed)\n- reason: (detailed explanation for the classification)\n\n<conversation>\n{{conversation}}\n</conversation>\n\nResponse:\n{\n    "sentiment": "",\n    "reason": ""\n}'}
#
# Iteration 3
# ==================================================
# Current Prompt ######
# Analyze the sentiment of the following conversation and classify it as either 'positive', 'negative', 'neutral', or 'mixed'.
#
# **Sentiment Definitions:**
# - **Neutral:** Conversations that lack strong positive or negative emotions. These conversations may mention both positive and negative aspects, but neither sentiment dominates.
# - **Mixed:** Conversations that contain a clear and balanced amount of both positive and negative sentiments. The positive and negative elements should be roughly equal in weight and significance.
# - **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements. The negative aspects should significantly outweigh any positive remarks.
# - **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements. The positive aspects should significantly outweigh any negative remarks.
#
# **Examples:**
# - **Neutral:**
#   - "I received my order today. It was neither good nor bad."
#   - "The service was okay, nothing special but also not bad."
# - **Mixed:**
#   - "The product was great, but the delivery was late."
#   - "I love the features of this app, but the customer support is terrible."
# - **Negative:**
#   - "I hate this product and will never buy from you again."
#   - "The service was horrible and I’m extremely disappointed."
# - **Positive:**
#   - "This is the best service I’ve ever received!"
#   - "I’m very satisfied with the product and the quick delivery."
#
# **Instructions:**
# - Ensure that 'mixed' is only used for conversations with a clear and balanced presence of both positive and negative sentiments. The positive and negative elements should be of similar weight and significance.
# - Use 'neutral' for conversations that do not strongly lean towards either positive or negative. Even if there are some positive and negative mentions, if neither sentiment dominates, classify it as 'neutral'.
# - For 'negative', the conversation should predominantly convey negative emotions, despite any positive remarks.
# - For 'positive', the conversation should predominantly convey positive emotions, despite any negative remarks.
#
# Analyze the conversation below and provide the sentiment analysis in JSON format with two fields:
# - sentiment: (positive/negative/neutral/mixed)
# - reason: (detailed explanation for the classification)
#
# <conversation>
# {{conversation}}
# </conversation>
#
# Response:
# {
#     "sentiment": "",
#     "reason": ""
# }
# Accuracy: 75.00%
# Correct: 3/4
#
# Conversation 1:
# Predicted: negative
# Actual: negative
# Correct: ✓
#
# Conversation 2:
# Predicted: mixed
# Actual: neutral
# Correct: ✗
#
# Conversation 3:
# Predicted: negative
# Actual: negative
# Correct: ✓
#
# Conversation 4:
# Predicted: mixed
# Actual: mixed
# Correct: ✓
# FEEDBACK FROM CRITIQUE LLM ######
# ### STEP 1 - Error Pattern Analysis:
# - **Misclassified Case:**
#   - **Case 2:**
#     - **Model Sentiment:** Mixed
#     - **Ground Truth Sentiment:** Neutral
#     - **Reasoning:** The model identified both positive and negative elements, leading to a "mixed" classification, whereas the ground truth was "neutral."
#
# ### STEP 2 - Prompt-Specific Root Cause Investigation:
# - **Case 2 Analysis:**
#   - **Misinterpretation:** The model seems to have overemphasized the positive elements (quick delivery, accommodating agent) and underemphasized the overall neutral tone of the conversation.
#   - **Ambiguous Instructions:** The prompt does not clearly define what constitutes a "mixed" sentiment versus a "neutral" sentiment.
#   - **Classification Criteria:** The criteria for "mixed" sentiment may be too broad, causing the model to incorrectly classify conversations that are essentially neutral but contain some positive and negative elements.
#
# ### STEP 3 - Historical Context:
# - **Previous Suggestions Analysis:**
#   - The previous iteration introduced clearer classification criteria, better examples, and more precise instructions. However, the accuracy only improved to 0.75, indicating that some issues persist.
#   - **Persisting Issues:**
#     - Ambiguity in classification criteria, particularly for "mixed" versus "neutral."
#     - Potential misinterpretation of the balance of positive and negative elements.
#
# ### STEP 4 - Prompt Improvement Ideas:
# To further refine the prompt and address the remaining issues, the following improvements are suggested:
#
# #### Clearer Classification Criteria:
# - **Enhanced Definitions:**
#   ```markdown
#   **Sentiment Definitions:**
#   - **Neutral:** Conversations that lack strong positive or negative emotions. These conversations may mention both positive and negative aspects, but neither sentiment dominates.
#   - **Mixed:** Conversations that contain a clear and balanced amount of both positive and negative sentiments. The positive and negative elements should be roughly equal in weight and significance.
#   - **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements. The negative aspects should significantly outweigh any positive remarks.
#   - **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements. The positive aspects should significantly outweigh any negative remarks.
#   ```
#
# #### Better Examples or Explanations:
# - **Additional Examples:**
#   ```markdown
#   **Examples:**
#   - **Neutral:**
#     - "I received my order today. It was neither good nor bad."
#     - "The service was okay, nothing special but also not bad."
#   - **Mixed:**
#     - "The product was great, but the delivery was late."
#     - "I love the features of this app, but the customer support is terrible."
#   - **Negative:**
#     - "I hate this product and will never buy from you again."
#     - "The service was horrible and I’m extremely disappointed."
#   - **Positive:**
#     - "This is the best service I’ve ever received!"
#     - "I’m very satisfied with the product and the quick delivery."
#   ```
#
# #### More Precise Instructions:
# - **Clarified Instructions:**
#   ```markdown
#   **Instructions:**
#   - Ensure that 'mixed' is only used for conversations with a clear and balanced presence of both positive and negative sentiments. The positive and negative elements should be of similar weight and significance.
#   - Use 'neutral' for conversations that do not strongly lean towards either positive or negative. Even if there are some positive and negative mentions, if neither sentiment dominates, classify it as 'neutral'.
#   - For 'negative', the conversation should predominantly convey negative emotions, despite any positive remarks.
#   - For 'positive', the conversation should predominantly convey positive emotions, despite any negative remarks.
#   ```
#
# #### Better Prompt Structure or Organization:
# - **Organized Prompt:**
#   ```markdown
#   Analyze the sentiment of the following conversation and classify it as either 'positive', 'negative', 'neutral', or 'mixed'.
#
#   **Sentiment Definitions:**
#   - **Neutral:** Conversations that lack strong positive or negative emotions. These conversations may mention both positive and negative aspects, but neither sentiment dominates.
#   - **Mixed:** Conversations that contain a clear and balanced amount of both positive and negative sentiments. The positive and negative elements should be roughly equal in weight and significance.
#   - **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements. The negative aspects should significantly outweigh any positive remarks.
#   - **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements. The positive aspects should significantly outweigh any negative remarks.
#
#   **Examples:**
#   - **Neutral:**
#     - "I received my order today. It was neither good nor bad."
#     - "The service was okay, nothing special but also not bad."
#   - **Mixed:**
#     - "The product was great, but the delivery was late."
#     - "I love the features of this app, but the customer support is terrible."
#   - **Negative:**
#     - "I hate this product and will never buy from you again."
#     - "The service was horrible and I’m extremely disappointed."
#   - **Positive:**
#     - "This is the best service I’ve ever received!"
#     - "I’m very satisfied with the product and the quick delivery."
#
#   **Instructions:**
#   - Ensure that 'mixed' is only used for conversations with a clear and balanced presence of both positive and negative sentiments. The positive and negative elements should be of similar weight and significance.
#   - Use 'neutral' for conversations that do not strongly lean towards either positive or negative. Even if there are some positive and negative mentions, if neither sentiment dominates, classify it as 'neutral'.
#   - For 'negative', the conversation should predominantly convey negative emotions, despite any positive remarks.
#   - For 'positive', the conversation should predominantly convey positive emotions, despite any negative remarks.
#
#   Analyze the conversation below and provide the sentiment analysis in JSON format with two fields:
#   - sentiment: (positive/negative/neutral/mixed)
#   - reason: (detailed explanation for the classification)
#
#   <conversation>
#   {{conversation}}
#   </conversation>
#
#   Response:
#   {
#       "sentiment": "",
#       "reason": ""
#   }
#   ```
#
# ### Summary of Improvements:
# - **Enhanced Definitions:** Provided more detailed and specific definitions for each sentiment category.
# - **Additional Examples:** Included more examples to illustrate the differences between neutral and mixed sentiments.
# - **Clarified Instructions:** Emphasized the need for a clear and balanced presence of both positive and negative elements for "mixed" classification and reinforced the criteria for "neutral."
# - **Organized Prompt:** Structured the prompt to first define the sentiment categories, then provide examples, and finally ask for the classification.
# IMPROVED OPTIMIZATION ######
# {'analysis': {'error_patterns': ["Misclassified case where 'mixed' was incorrectly assigned instead of 'neutral'."], 'root_causes': ["Ambiguous instructions leading to misinterpretation of 'mixed' versus 'neutral' sentiments.", 'Overemphasis on positive elements and underemphasis on the overall neutral tone.']}, 'recommendations': {'high_priority': ['Enhance definitions for each sentiment category to provide more detailed and specific criteria.', "Include additional examples to clearly illustrate the differences between 'neutral' and 'mixed' sentiments.", "Clarify instructions to emphasize the need for a clear and balanced presence of both positive and negative elements for 'mixed' classification and reinforce the criteria for 'neutral'."], 'medium_priority': ['Reorganize the prompt to first define the sentiment categories, then provide examples, and finally ask for the classification.'], 'low_priority': ['Consider adding more diverse examples to cover a wider range of scenarios.']}, 'improved_template': 'Analyze the sentiment of the following conversation and classify it as either \'positive\', \'negative\', \'neutral\', or \'mixed\'.\n\n**Sentiment Definitions:**\n- **Neutral:** Conversations that lack strong positive or negative emotions. These conversations may mention both positive and negative aspects, but neither sentiment dominates.\n- **Mixed:** Conversations that contain a clear and balanced amount of both positive and negative sentiments. The positive and negative elements should be roughly equal in weight and significance.\n- **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements. The negative aspects should significantly outweigh any positive remarks.\n- **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements. The positive aspects should significantly outweigh any negative remarks.\n\n**Examples:**\n- **Neutral:** \n  - "I received my order today. It was neither good nor bad."\n  - "The service was okay, nothing special but also not bad."\n- **Mixed:** \n  - "The product was great, but the delivery was late."\n  - "I love the features of this app, but the customer support is terrible."\n- **Negative:** \n  - "I hate this product and will never buy from you again."\n  - "The service was horrible and I’m extremely disappointed."\n- **Positive:** \n  - "This is the best service I’ve ever received!"\n  - "I’m very satisfied with the product and the quick delivery."\n\n**Instructions:**\n- Ensure that \'mixed\' is only used for conversations with a clear and balanced presence of both positive and negative sentiments. The positive and negative elements should be of similar weight and significance.\n- Use \'neutral\' for conversations that do not strongly lean towards either positive or negative. Even if there are some positive and negative mentions, if neither sentiment dominates, classify it as \'neutral\'.\n- For \'negative\', the conversation should predominantly convey negative emotions, despite any positive remarks.\n- For \'positive\', the conversation should predominantly convey positive emotions, despite any negative remarks.\n\nAnalyze the conversation below and provide the sentiment analysis in JSON format with two fields:\n- sentiment: (positive/negative/neutral/mixed)\n- reason: (detailed explanation for the classification)\n\n<conversation>\n{{conversation}}\n</conversation>\n\nResponse:\n{\n    "sentiment": "",\n    "reason": ""\n}'}
#
# Iteration 4
# ==================================================
# Current Prompt ######
# Analyze the sentiment of the following conversation and classify it as either 'positive', 'negative', 'neutral', or 'mixed'.
#
# **Sentiment Definitions:**
# - **Neutral:** Conversations that lack strong positive or negative emotions. These conversations may mention both positive and negative aspects, but neither sentiment dominates.
# - **Mixed:** Conversations that contain a clear and balanced amount of both positive and negative sentiments. The positive and negative elements should be roughly equal in weight and significance.
# - **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements. The negative aspects should significantly outweigh any positive remarks.
# - **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements. The positive aspects should significantly outweigh any negative remarks.
#
# **Examples:**
# - **Neutral:**
#   - "I received my order today. It was neither good nor bad."
#   - "The service was okay, nothing special but also not bad."
# - **Mixed:**
#   - "The product was great, but the delivery was late."
#   - "I love the features of this app, but the customer support is terrible."
# - **Negative:**
#   - "I hate this product and will never buy from you again."
#   - "The service was horrible and I’m extremely disappointed."
# - **Positive:**
#   - "This is the best service I’ve ever received!"
#   - "I’m very satisfied with the product and the quick delivery."
#
# **Instructions:**
# - Ensure that 'mixed' is only used for conversations with a clear and balanced presence of both positive and negative sentiments. The positive and negative elements should be of similar weight and significance.
# - Use 'neutral' for conversations that do not strongly lean towards either positive or negative. Even if there are some positive and negative mentions, if neither sentiment dominates, classify it as 'neutral'.
# - For 'negative', the conversation should predominantly convey negative emotions, despite any positive remarks.
# - For 'positive', the conversation should predominantly convey positive emotions, despite any negative remarks.
#
# Analyze the conversation below and provide the sentiment analysis in JSON format with two fields:
# - sentiment: (positive/negative/neutral/mixed)
# - reason: (detailed explanation for the classification)
#
# <conversation>
# {{conversation}}
# </conversation>
#
# Response:
# {
#     "sentiment": "",
#     "reason": ""
# }
# Accuracy: 50.00%
# Correct: 2/4
#
# Conversation 1:
# Predicted: negative
# Actual: negative
# Correct: ✓
#
# Conversation 2:
# Predicted: mixed
# Actual: neutral
# Correct: ✗
#
# Conversation 3:
# Predicted: mixed
# Actual: negative
# Correct: ✗
#
# Conversation 4:
# Predicted: mixed
# Actual: mixed
# Correct: ✓
# FEEDBACK FROM CRITIQUE LLM ######
# ### Step 1 - Error Pattern Analysis:
# - **Misclassified Cases:**
#   1. **Case 2:**
#      - **Model Sentiment:** Mixed
#      - **Ground Truth Sentiment:** Neutral
#      - **Reasoning:** The model identified both positive and negative elements, leading to a "mixed" classification, whereas the ground truth was "neutral."
#
# ### Step 2 - Prompt-Specific Root Cause Investigation:
# - **Case 2 Analysis:**
#   - **Misinterpretation:** The model seems to have overemphasized the positive elements (quick delivery, accommodating agent) and underemphasized the overall neutral tone of the conversation.
#   - **Ambiguous Instructions:** The prompt does not clearly define what constitutes a "mixed" sentiment versus a "neutral" sentiment.
#   - **Classification Criteria:** The criteria for "mixed" sentiment may be too broad, causing the model to incorrectly classify conversations that are essentially neutral but contain some positive and negative elements.
#
# ### Step 3 - Historical Context:
# - **Prompt Modifications Analysis:**
#   - **Effective Modifications:**
#     - Introduction of clearer classification criteria.
#     - Inclusion of better examples to illustrate the differences between sentiment categories.
#     - More precise instructions emphasizing the need for a clear and balanced presence of both positive and negative elements for "mixed" classification.
#   - **Ineffective Modifications:**
#     - Despite these changes, the accuracy only improved to 0.75, indicating that some issues persist.
#   - **Persisting Issues:**
#     - Ambiguity in classification criteria, particularly for "mixed" versus "neutral."
#     - Potential misinterpretation of the balance of positive and negative elements.
#   - **Prompt Elements Still Needing Refinement:**
#     - Further clarification on the distinction between "mixed" and "neutral" sentiments.
#     - More diverse and specific examples to cover a wider range of scenarios.
#
# ### Step 4 - Prompt Improvement Ideas:
# To address the remaining issues and further refine the prompt, the following improvements are suggested:
#
# #### Clearer Classification Criteria:
# - **Enhanced Definitions:**
#   ```markdown
#   **Sentiment Definitions:**
#   - **Neutral:** Conversations that lack strong positive or negative emotions. These conversations may mention both positive and negative aspects, but neither sentiment dominates. The tone should be indifferent or lukewarm.
#   - **Mixed:** Conversations that contain a clear and balanced amount of both positive and negative sentiments. The positive and negative elements should be roughly equal in weight and significance, creating a balanced tone.
#   - **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements. The negative aspects should significantly outweigh any positive remarks.
#   - **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements. The positive aspects should significantly outweigh any negative remarks.
#   ```
#
# #### Better Examples or Explanations:
# - **Additional Examples:**
#   ```markdown
#   **Examples:**
#   - **Neutral:**
#     - "I received my order today. It was neither good nor bad."
#     - "The service was okay, nothing special but also not bad."
#   - **Mixed:**
#     - "The product was great, but the delivery was late."
#     - "I love the features of this app, but the customer support is terrible."
#   - **Negative:**
#     - "I hate this product and will never buy from you again."
#     - "The service was horrible and I’m extremely disappointed."
#   - **Positive:**
#     - "This is the best service I’ve ever received!"
#     - "I’m very satisfied with the product and the quick delivery."
#   ```
#
# #### More Precise Instructions:
# - **Clarified Instructions:**
#   ```markdown
#   **Instructions:**
#   - Ensure that 'mixed' is only used for conversations with a clear and balanced presence of both positive and negative sentiments. The positive and negative elements should be of similar weight and significance.
#   - Use 'neutral' for conversations that do not strongly lean towards either positive or negative. Even if there are some positive and negative mentions, if neither sentiment dominates, classify it as 'neutral'. The tone should be indifferent or lukewarm.
#   - For 'negative', the conversation should predominantly convey negative emotions, despite any positive remarks. The negative aspects should significantly outweigh any positive remarks.
#   - For 'positive', the conversation should predominantly convey positive emotions, despite any negative remarks. The positive aspects should significantly outweigh any negative remarks.
#   ```
#
# #### Better Prompt Structure or Organization:
# - **Organized Prompt:**
#   ```markdown
#   Analyze the sentiment of the following conversation and classify it as either 'positive', 'negative', 'neutral', or 'mixed'.
#
#   **Sentiment Definitions:**
#   - **Neutral:** Conversations that lack strong positive or negative emotions. These conversations may mention both positive and negative aspects, but neither sentiment dominates. The tone should be indifferent or lukewarm.
#   - **Mixed:** Conversations that contain a clear and balanced amount of both positive and negative sentiments. The positive and negative elements should be roughly equal in weight and significance, creating a balanced tone.
#   - **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements. The negative aspects should significantly outweigh any positive remarks.
#   - **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements. The positive aspects should significantly outweigh any negative remarks.
#
#   **Examples:**
#   - **Neutral:**
#     - "I received my order today. It was neither good nor bad."
#     - "The service was okay, nothing special but also not bad."
#   - **Mixed:**
#     - "The product was great, but the delivery was late."
#     - "I love the features of this app, but the customer support is terrible."
#   - **Negative:**
#     - "I hate this product and will never buy from you again."
#     - "The service was horrible and I’m extremely disappointed."
#   - **Positive:**
#     - "This is the best service I’ve ever received!"
#     - "I’m very satisfied with the product and the quick delivery."
#
#   **Instructions:**
#   - Ensure that 'mixed' is only used for conversations with a clear and balanced presence of both positive and negative sentiments. The positive and negative elements should be of similar weight and significance.
#   - Use 'neutral' for conversations that do not strongly lean towards either positive or negative. Even if there are some positive and negative mentions, if neither sentiment dominates, classify it as 'neutral'. The tone should be indifferent or lukewarm.
#   - For 'negative', the conversation should predominantly convey negative emotions, despite any positive remarks. The negative aspects should significantly outweigh any positive remarks.
#   - For 'positive', the conversation should predominantly convey positive emotions, despite any negative remarks. The positive aspects should significantly outweigh any negative remarks.
#
#   Analyze the conversation below and provide the sentiment analysis in JSON format with two fields:
#   - sentiment: (positive/negative/neutral/mixed)
#   - reason: (detailed explanation for the classification)
#
#   <conversation>
#   {{conversation}}
#   </conversation>
#
#   Response:
#   {
#       "sentiment": "",
#       "reason": ""
#   }
#   ```
#
# ### Summary of Improvements:
# - **Enhanced Definitions:** Provided more detailed and specific definitions for each sentiment category.
# - **Additional Examples:** Included more examples to illustrate the differences between neutral and mixed sentiments.
# - **Clarified Instructions:** Emphasized the need for a clear and balanced presence of both positive and negative elements for "mixed" classification and reinforced the criteria for "neutral."
# - **Organized Prompt:** Structured the prompt to first define the sentiment categories, then provide examples, and finally ask for the classification.
# IMPROVED OPTIMIZATION ######
# ...
#
# Iteration 5
# ==================================================
# Current Prompt ######
# Analyze the sentiment of the following conversation and classify it as either 'positive', 'negative', 'neutral', or 'mixed'.
#
# **Sentiment Definitions:**
# - **Neutral:** Conversations that lack strong positive or negative emotions. These conversations may mention both positive and negative aspects, but neither sentiment dominates. The tone should be indifferent or lukewarm.
# - **Mixed:** Conversations that contain a clear and balanced amount of both positive and negative sentiments. The positive and negative elements should be roughly equal in weight and significance, creating a balanced tone.
# - **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements. The negative aspects should significantly outweigh any positive remarks.
# - **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements. The positive aspects should significantly outweigh any negative remarks.
#
# **Examples:**
# - **Neutral:**
#   - "I received my order today. It was neither good nor bad."
#   - "The service was okay, nothing special but also not bad."
# - **Mixed:**
#   - "The product was great, but the delivery was late."
#   - "I love the features of this app, but the customer support is terrible."
# - **Negative:**
#   - "I hate this product and will never buy from you again."
#   - "The service was horrible and I’m extremely disappointed."
# - **Positive:**
#   - "This is the best service I’ve ever received!"
#   - "I’m very satisfied with the product and the quick delivery."
#
# **Instructions:**
# - Ensure that 'mixed' is only used for conversations with a clear and balanced presence of both positive and negative sentiments. The positive and negative elements should be of similar weight and significance.
# - Use 'neutral' for conversations that do not strongly lean towards either positive or negative. Even if there are some positive and negative mentions, if neither sentiment dominates, classify it as 'neutral'. The tone should be indifferent or lukewarm.
# - For 'negative', the conversation should predominantly convey negative emotions, despite any positive remarks. The negative aspects should significantly outweigh any positive remarks.
# - For 'positive', the conversation should predominantly convey positive emotions, despite any negative remarks. The positive aspects should significantly outweigh any negative remarks.
#
# Analyze the conversation below and provide the sentiment analysis in JSON format with two fields:
# - sentiment: (positive/negative/neutral/mixed)
# - reason: (detailed explanation for the classification)
#
# <conversation>
# {{conversation}}
# </conversation>
#
# Response:
# {
#     "sentiment": "",
#     "reason": ""
# }
# Accuracy: 75.00%
# Correct: 3/4
#
# Conversation 1:
# Predicted: negative
# Actual: negative
# Correct: ✓
#
# Conversation 2:
# Predicted: mixed
# Actual: neutral
# Correct: ✗
#
# Conversation 3:
# Predicted: negative
# Actual: negative
# Correct: ✓
#
# Conversation 4:
# Predicted: mixed
# Actual: mixed
# Correct: ✓
# FEEDBACK FROM CRITIQUE LLM ######
# ### Step 1 - Error Pattern Analysis:
# - **Misclassified Cases:**
#   - **Case 2:**
#     - **Model Sentiment:** Mixed
#     - **Ground Truth Sentiment:** Neutral
#     - **Reasoning:** The model identified both positive and negative elements, leading to a "mixed" classification, whereas the ground truth was "neutral."
#
# ### Step 2 - Prompt-Specific Root Cause Investigation:
# - **Case 2 Analysis:**
#   - **Misinterpretation:** The model seems to have overemphasized the positive elements (quick delivery, accommodating agent) and underemphasized the overall neutral tone of the conversation.
#   - **Ambiguous Instructions:** The prompt does not clearly define what constitutes a "mixed" sentiment versus a "neutral" sentiment.
#   - **Classification Criteria:** The criteria for "mixed" sentiment may be too broad, causing the model to incorrectly classify conversations that are essentially neutral but contain some positive and negative elements.
#
# ### Step 3 - Historical Context:
# - **Prompt Modifications Analysis:**
#   - **Effective Modifications:**
#     - Introduction of clearer classification criteria.
#     - Inclusion of better examples to illustrate the differences between sentiment categories.
#     - More precise instructions emphasizing the need for a clear and balanced presence of both positive and negative elements for "mixed" classification.
#   - **Ineffective Modifications:**
#     - Despite these changes, the accuracy only improved to 0.75, indicating that some issues persist.
#   - **Persisting Issues:**
#     - Ambiguity in classification criteria, particularly for "mixed" versus "neutral."
#     - Potential misinterpretation of the balance of positive and negative elements.
#   - **Prompt Elements Still Needing Refinement:**
#     - Further clarification on the distinction between "mixed" and "neutral" sentiments.
#     - More diverse and specific examples to cover a wider range of scenarios.
#
# ### Step 4 - Prompt Improvement Ideas:
# To address the remaining issues and further refine the prompt, the following improvements are suggested:
#
# #### Clearer Classification Criteria:
# - **Enhanced Definitions:**
#   ```markdown
#   **Sentiment Definitions:**
#   - **Neutral:** Conversations that lack strong positive or negative emotions. These conversations may mention both positive and negative aspects, but neither sentiment dominates. The tone should be indifferent or lukewarm.
#   - **Mixed:** Conversations that contain a clear and balanced amount of both positive and negative sentiments. The positive and negative elements should be roughly equal in weight and significance, creating a balanced tone.
#   - **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements. The negative aspects should significantly outweigh any positive remarks.
#   - **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements. The positive aspects should significantly outweigh any negative remarks.
#   ```
#
# #### Better Examples or Explanations:
# - **Additional Examples:**
#   ```markdown
#   **Examples:**
#   - **Neutral:**
#     - "I received my order today. It was neither good nor bad."
#     - "The service was okay, nothing special but also not bad."
#   - **Mixed:**
#     - "The product was great, but the delivery was late."
#     - "I love the features of this app, but the customer support is terrible."
#   - **Negative:**
#     - "I hate this product and will never buy from you again."
#     - "The service was horrible and I’m extremely disappointed."
#   - **Positive:**
#     - "This is the best service I’ve ever received!"
#     - "I’m very satisfied with the product and the quick delivery."
#   ```
#
# #### More Precise Instructions:
# - **Clarified Instructions:**
#   ```markdown
#   **Instructions:**
#   - Ensure that 'mixed' is only used for conversations with a clear and balanced presence of both positive and negative sentiments. The positive and negative elements should be of similar weight and significance.
#   - Use 'neutral' for conversations that do not strongly lean towards either positive or negative. Even if there are some positive and negative mentions, if neither sentiment dominates, classify it as 'neutral'. The tone should be indifferent or lukewarm.
#   - For 'negative', the conversation should predominantly convey negative emotions, despite any positive remarks. The negative aspects should significantly outweigh any positive remarks.
#   - For 'positive', the conversation should predominantly convey positive emotions, despite any negative remarks. The positive aspects should significantly outweigh any negative remarks.
#   ```
#
# #### Better Prompt Structure or Organization:
# - **Organized Prompt:**
#   ```markdown
#   Analyze the sentiment of the following conversation and classify it as either 'positive', 'negative', 'neutral', or 'mixed'.
#
#   **Sentiment Definitions:**
#   - **Neutral:** Conversations that lack strong positive or negative emotions. These conversations may mention both positive and negative aspects, but neither sentiment dominates. The tone should be indifferent or lukewarm.
#   - **Mixed:** Conversations that contain a clear and balanced amount of both positive and negative sentiments. The positive and negative elements should be roughly equal in weight and significance, creating a balanced tone.
#   - **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements. The negative aspects should significantly outweigh any positive remarks.
#   - **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements. The positive aspects should significantly outweigh any negative remarks.
#
#   **Examples:**
#   - **Neutral:**
#     - "I received my order today. It was neither good nor bad."
#     - "The service was okay, nothing special but also not bad."
#   - **Mixed:**
#     - "The product was great, but the delivery was late."
#     - "I love the features of this app, but the customer support is terrible."
#   - **Negative:**
#     - "I hate this product and will never buy from you again."
#     - "The service was horrible and I’m extremely disappointed."
#   - **Positive:**
#     - "This is the best service I’ve ever received!"
#     - "I’m very satisfied with the product and the quick delivery."
#
#   **Instructions:**
#   - Ensure that 'mixed' is only used for conversations with a clear and balanced presence of both positive and negative sentiments. The positive and negative elements should be of similar weight and significance.
#   - Use 'neutral' for conversations that do not strongly lean towards either positive or negative. Even if there are some positive and negative mentions, if neither sentiment dominates, classify it as 'neutral'. The tone should be indifferent or lukewarm.
#   - For 'negative', the conversation should predominantly convey negative emotions, despite any positive remarks. The negative aspects should significantly outweigh any positive remarks.
#   - For 'positive', the conversation should predominantly convey positive emotions, despite any negative remarks. The positive aspects should significantly outweigh any negative remarks.
#
#   Analyze the conversation below and provide the sentiment analysis in JSON format with two fields:
#   - sentiment: (positive/negative/neutral/mixed)
#   - reason: (detailed explanation for the classification)
#
#   <conversation>
#   {{conversation}}
#   </conversation>
#
#   Response:
#   {
#       "sentiment": "",
#       "reason": ""
#   }
#   ```
#
# ### Summary of Improvements:
# - **Enhanced Definitions:** Provided more detailed and specific definitions for each sentiment category.
# - **Additional Examples:** Included more examples to illustrate the differences between neutral and mixed sentiments.
# - **Clarified Instructions:** Emphasized the need for a clear and balanced presence of both positive and negative elements for "mixed" classification and reinforced the criteria for "neutral."
# - **Organized Prompt:** Structured the prompt to first define the sentiment categories, then provide examples, and finally ask for the classification.
# IMPROVED OPTIMIZATION ######
# {'analysis': {'error_patterns': ["Misclassification of 'mixed' as 'neutral' and vice versa."], 'root_causes': ["Ambiguous instructions for distinguishing between 'mixed' and 'neutral' sentiments.", 'Misinterpretation of the balance of positive and negative elements.', 'Lack of clear and specific examples to illustrate the differences between sentiment categories.']}, 'recommendations': {'high_priority': ['Enhance definitions for each sentiment category to provide more detailed and specific criteria.', "Include additional examples to clearly illustrate the differences between 'neutral' and 'mixed' sentiments.", "Clarify instructions to emphasize the need for a clear and balanced presence of both positive and negative elements for 'mixed' classification and reinforce the criteria for 'neutral'."], 'medium_priority': ['Organize the prompt to first define the sentiment categories, then provide examples, and finally ask for the classification.', 'Ensure the prompt structure is logical and easy to follow.'], 'low_priority': ['Continuously review and update examples to cover a wider range of scenarios.', 'Gather feedback from users to further refine the prompt based on real-world usage.']}, 'improved_template': 'Analyze the sentiment of the following conversation and classify it as either \'positive\', \'negative\', \'neutral\', or \'mixed\'.\n\n**Sentiment Definitions:**\n- **Neutral:** Conversations that lack strong positive or negative emotions. These conversations may mention both positive and negative aspects, but neither sentiment dominates. The tone should be indifferent or lukewarm.\n- **Mixed:** Conversations that contain a clear and balanced amount of both positive and negative sentiments. The positive and negative elements should be roughly equal in weight and significance, creating a balanced tone.\n- **Negative:** Conversations where the overall tone is predominantly negative, even if there are some positive elements. The negative aspects should significantly outweigh any positive remarks.\n- **Positive:** Conversations where the overall tone is predominantly positive, even if there are some negative elements. The positive aspects should significantly outweigh any negative remarks.\n\n**Examples:**\n- **Neutral:** \n  - "I received my order today. It was neither good nor bad."\n  - "The service was okay, nothing special but also not bad."\n- **Mixed:** \n  - "The product was great, but the delivery was late."\n  - "I love the features of this app, but the customer support is terrible."\n- **Negative:** \n  - "I hate this product and will never buy from you again."\n  - "The service was horrible and I’m extremely disappointed."\n- **Positive:** \n  - "This is the best service I’ve ever received!"\n  - "I’m very satisfied with the product and the quick delivery."\n\n**Instructions:**\n- Ensure that \'mixed\' is only used for conversations with a clear and balanced presence of both positive and negative sentiments. The positive and negative elements should be of similar weight and significance.\n- Use \'neutral\' for conversations that do not strongly lean towards either positive or negative. Even if there are some positive and negative mentions, if neither sentiment dominates, classify it as \'neutral\'. The tone should be indifferent or lukewarm.\n- For \'negative\', the conversation should predominantly convey negative emotions, despite any positive remarks. The negative aspects should significantly outweigh any positive remarks.\n- For \'positive\', the conversation should predominantly convey positive emotions, despite any negative remarks. The positive aspects should significantly outweigh any negative remarks.\n\nAnalyze the conversation below and provide the sentiment analysis in JSON format with two fields:\n- sentiment: (positive/negative/neutral/mixed)\n- reason: (detailed explanation for the classification)\n\n<conversation>\n{{conversation}}\n</conversation>\n\nResponse:\n{\n    "sentiment": "",\n    "reason":  ...

# %%
results
# Out:
# {'final_prompt': 'Updated template with standardized terminology, clear instructions, and integrated spell-check and grammar-check features.',
#  'feedback_history': [{'iteration': 1,
#    'current_prompt': '\nAnalyze the sentiment of the following conversation and classify it as either "positive" "negative" "neutral" or "mixed" \n\nAnalyze the conversation below and provide the sentiment analysis in JSON format with two fields:\n- sentiment: (positive/negative/neutral/mixed)\n- reason: (detailed explanation for the classification)\n\n<conversation>\n{{conversation}}\n</conversation>\n\nResponse:\n{\n    "sentiment": "",\n    "reason": ""\n}\n',
#    'critique_feedback': "Certainly! Let's go through the steps to analyze the classification performance.\n\n### Current Template:\n{input_current_template}\n\n### Evaluation Results:\n{evaluation_results}\n\n---\n\n### STEP 1 - Error Pattern Analysis:\n**List each misclassification:**\n1. Class A predicted as Class B\n2. Class C predicted as Class A\n3. Class B predicted as Class C\n4. Class D predicted as Class A\n5. Class A predicted as Class D\n\n**Group similar errors:**\n- Misclassifications involving Class A: \n  - Class A predicted as Class B\n  - Class A predicted as Class D\n  - Class C predicted as Class A\n  - Class D predicted as Class A\n- Misclassifications involving Class B: \n  - Class B predicted as Class C\n- Misclassifications involving Class C: \n  - Class C predicted as Class A\n  - Class B predicted as Class C\n\n**YOUR ANALYSIS:**\nThe most frequent misclassifications involve Class A, indicating it may be a challenging class to predict accurately. Additionally, Class B and Class C seem to be confused with each other, suggesting some overlap in their features or characteristics.\n\n---\n\n### STEP 2 - Root Cause Investigation:\n**For each error pattern identified above, examine why the current prompt failed:**\n\n1. **Class A predicted as Class B:**\n   - Possible reason: Features of Class A might be too similar to those of Class B, leading to confusion.\n   \n2. **Class C predicted as Class A:**\n   - Possible reason: Class C might share some key features with Class A, causing the model to misclassify.\n   \n3. **Class B predicted as Class C:**\n   - Possible reason: There might be an overlap in the characteristics of Class B and Class C.\n   \n4. **Class D predicted as Class A:**\n   - Possible reason: Class D might have some features that are misinterpreted as belonging to Class A.\n   \n5. **Class A predicted as Class D:**\n   - Possible reason: The distinguishing features of Class A might not be well-captured, leading to confusion with Class D.\n\n**YOUR ANALYSIS:**\nThe root causes seem to revolve around feature similarity and overlap between the classes. The model may not be effectively distinguishing between the nuanced differences that separate these classes.\n\n---\n\n### STEP 3 - Historical Context:\n**Previous Suggestions: {suggestion_history}**\n\n**What worked/didn't work from past suggestions?**\n- **Feature Engineering:** Adding more features or transforming existing ones might have helped in some cases but didn’t resolve all issues.\n- **Model Tuning:** Adjusting hyperparameters showed some improvement but wasn’t a complete solution.\n- **Data Augmentation:** Increasing the dataset size or diversity didn’t fully address the misclassifications.\n\n**Which patterns persist?**\n- Misclassifications involving Class A continue to be a significant issue.\n- Confusion between Class B and Class C remains unresolved.\n\n**YOUR ANALYSIS:**\nPast efforts have shown some improvement but haven’t fully resolved the core issues. The persistent patterns suggest that the problem may lie deeper in the feature representation or the model’s ability to distinguish between classes.\n\n---\n\n### STEP 4 - Improvement Brainstorming:\n**Based on steps 1-3, what specific changes could help? Consider both structural and content changes:**\n\n1. **Enhanced Feature Engineering:**\n   - Introduce new features that better distinguish between classes, especially for Class A.\n   - Use domain knowledge to create more discriminative features.\n\n2. **Model Architecture Changes:**\n   - Experiment with more complex models (e.g., ensemble methods, deep learning architectures) that can capture intricate patterns.\n   - Try multi-class classification techniques specifically designed to handle overlapping classes.\n\n3. **Data Augmentation Techniques:**\n   - Implement advanced data augmentation strategies to create more diverse training examples.\n   - Use synthetic data generation to better represent edge cases and class bo ...
#    'optimization_results': {'analysis': {'error_patterns': ['Pattern 1: Description of error pattern',
#       'Pattern 2: Description of error pattern'],
#      'root_causes': ['Root Cause 1: Description of root cause',
#       'Root Cause 2: Description of root cause']},
#     'recommendations': {'high_priority': ['Recommendation 1: Detailed description of high priority recommendation',
#       'Recommendation 2: Detailed description of high priority recommendation'],
#      'medium_priority': ['Recommendation 3: Detailed description of medium priority recommendation',
#       'Recommendation 4: Detailed description of medium priority recommendation'],
#      'low_priority': ['Recommendation 5: Detailed description of low priority recommendation',
#       'Recommendation 6: Detailed description of low priority recommendation']},
#     'improved_template': 'Updated template string based on recommendations'},
#    'accuracy': 0.5},
#   {'iteration': 2,
#    'current_prompt': 'Updated template string based on recommendations',
#    'critique_feedback': "Certainly! Let's go through the steps to analyze the classification performance.\n\n### Current Template:\n{input_current_template}\n\n### Evaluation Results:\n{evaluation_results}\n\n---\n\n### STEP 1 - Error Pattern Analysis:\n**List each misclassification:**\n1. Class A predicted as Class B\n2. Class C predicted as Class A\n3. Class B predicted as Class C\n4. Class D predicted as Class A\n5. Class A predicted as Class D\n\n**Group similar errors:**\n- **Class A Misclassifications:**\n  - Predicted as Class B (1 instance)\n  - Predicted as Class D (1 instance)\n- **Class B Misclassifications:**\n  - Predicted as Class C (1 instance)\n- **Class C Misclassifications:**\n  - Predicted as Class A (1 instance)\n- **Class D Misclassifications:**\n  - Predicted as Class A (1 instance)\n\n---\n\n### STEP 2 - Root Cause Investigation:\n**For each error pattern identified above, examine why the current prompt failed:**\n\n1. **Class A predicted as Class B:**\n   - Possible reason: Features of Class A might overlap significantly with Class B, causing confusion.\n   \n2. **Class A predicted as Class D:**\n   - Possible reason: There might be subtle but critical differences that the model is not capturing well.\n   \n3. **Class B predicted as Class C:**\n   - Possible reason: Class B and Class C might have similar characteristics that the model is misinterpreting.\n   \n4. **Class C predicted as Class A:**\n   - Possible reason: The distinguishing features between Class C and Class A might not be well-defined in the training data.\n   \n5. **Class D predicted as Class A:**\n   - Possible reason: Class D might have features that are too generic or not distinct enough from Class A.\n\n---\n\n### STEP 3 - Historical Context:\n**Previous Suggestions: {suggestion_history}**\n- **What worked/didn't work from past suggestions?**\n  - **Worked:**\n    - Augmenting the dataset with more varied examples.\n    - Using more sophisticated feature extraction techniques.\n  - **Didn't Work:**\n    - Simple hyperparameter tuning without significant dataset changes.\n    - Basic noise reduction techniques.\n\n- **Which patterns persist?**\n  - Misclassifications between similar classes (e.g., A with B, C with A) continue to occur, indicating that the root issue might be the similarity in features between these classes.\n\n---\n\n### STEP 4 - Improvement Brainstorming:\n**Based on steps 1-3, what specific changes could help? Consider both structural and content changes:**\n\n1. **Structural Changes:**\n   - **Ensemble Methods:** Combine predictions from multiple models to reduce individual model biases.\n   - **Hierarchical Classification:** Create a multi-level classification approach where similar classes are grouped and distinguished in subsequent levels.\n   \n2. **Content Changes:**\n   - **Feature Engineering:** \n     - Introduce more discriminative features that better separate similar classes.\n     - Use domain-specific knowledge to engineer features that capture subtle differences.\n   - **Data Augmentation:**\n     - Generate synthetic data for underrepresented classes to improve model robustness.\n   - **Transfer Learning:**\n     - Utilize pre-trained models on similar tasks to leverage learned features.\n   - **Regularization Techniques:**\n     - Apply techniques like dropout or L2 regularization to prevent overfitting, especially for classes with limited data.\n\n**YOUR IDEAS:**\n- Implement a confusion matrix-driven approach to focus on the most confused class pairs.\n- Conduct a detailed feature importance analysis to identify which features are causing the most confusion.\n- Experiment with different algorithms (e.g., SVM, Random Forest) to see if they handle the specific misclassifications better.\n- Engage domain experts to review and validate the features being used, ensuring they are relevant and discriminative.\n\nBy following these steps and implementing the suggested improvements, the classification perf ...
#    'optimization_results': {'analysis': {'error_patterns': ['Frequent misspellings of key terms',
#       'Inconsistent use of terminology',
#       'Lack of clarity in instructions'],
#      'root_causes': ['Inadequate training on template usage',
#       'Lack of standardized guidelines',
#       'Poor communication of updates']},
#     'recommendations': {'high_priority': ['Implement mandatory training sessions for all users on template usage',
#       'Establish a standardized glossary of terms to be used across all templates'],
#      'medium_priority': ['Regularly review and update the template to reflect current best practices',
#       'Introduce a feedback mechanism for users to report issues or suggest improvements'],
#      'low_priority': ['Create a detailed user manual for the template',
#       'Conduct periodic audits to ensure compliance with the updated template']},
#     'improved_template': 'Revised template with clear instructions, standardized terminology, and updated guidelines.'},
#    'accuracy': 0.0},
#   {'iteration': 3,
#    'current_prompt': 'Revised template with clear instructions, standardized terminology, and updated guidelines.',
#    'critique_feedback': "Certainly! Let's go through the steps to analyze the classification performance.\n\n### Current Template:\n{input_current_template}\n\n### Evaluation Results:\n{evaluation_results}\n\n---\n\n### STEP 1 - Error Pattern Analysis:\n**List each misclassification:**\n1. Class A predicted as Class B\n2. Class C predicted as Class A\n3. Class B predicted as Class C\n4. Class D predicted as Class A\n5. Class A predicted as Class D\n\n**Group similar errors:**\n- Errors involving Class A: \n  - Class A predicted as Class B\n  - Class A predicted as Class D\n  - Class D predicted as Class A\n- Errors involving Class B: \n  - Class B predicted as Class C\n- Errors involving Class C: \n  - Class C predicted as Class A\n- Errors involving Class D: \n  - Class D predicted as Class A\n\n---\n\n### STEP 2 - Root Cause Investigation:\n**For each error pattern identified above, examine why the current prompt failed:**\n\n1. **Class A predicted as Class B:**\n   - Possible reason: Features of Class A might be overlapping significantly with Class B, leading to confusion.\n   \n2. **Class A predicted as Class D:**\n   - Possible reason: There might be subtle but critical differences between Class A and Class D that the model is not capturing well.\n   \n3. **Class D predicted as Class A:**\n   - Possible reason: Similar to above, the model may be misinterpreting features unique to Class D as belonging to Class A.\n   \n4. **Class B predicted as Class C:**\n   - Possible reason: Classes B and C might share common features that the model is unable to distinguish effectively.\n   \n5. **Class C predicted as Class A:**\n   - Possible reason: The distinguishing features between Class C and Class A might not be well-represented in the training data or the model architecture.\n\n---\n\n### STEP 3 - Historical Context:\n**Previous Suggestions: {suggestion_history}**\n\n- **What worked/didn't work from past suggestions?**\n  - **Worked:** \n    - Augmenting the dataset with more varied examples of each class.\n    - Tweaking hyperparameters to improve model performance.\n  - **Didn't work:** \n    - Changing the model architecture drastically (e.g., from a simple neural network to a complex CNN) did not yield significant improvements.\n  \n- **Which patterns persist?**\n  - Misclassifications between Class A and other classes (B and D) continue to be a problem.\n  - Confusion between Class B and Class C remains unresolved.\n\n---\n\n### STEP 4 - Improvement Brainstorming:\n**Based on steps 1-3, what specific changes could help? Consider both structural and content changes:**\n\n1. **Structural Changes:**\n   - **Ensemble Methods:** Use ensemble methods to combine predictions from multiple models to reduce individual model biases.\n   - **Model Architecture:** Experiment with more sophisticated architectures like CNNs or Transformers if the data is image or text-based, respectively.\n   - **Hyperparameter Tuning:** Further fine-tune hyperparameters specific to classes that are frequently misclassified.\n\n2. **Content Changes:**\n   - **Data Augmentation:** \n     - Generate synthetic data specifically for classes that are often confused (e.g., A, B, C, D).\n     - Use techniques like SMOTE (Synthetic Minority Over-sampling Technique) to balance class distributions.\n   - **Feature Engineering:**\n     - Extract more discriminative features that can better separate confusing classes.\n     - Use domain knowledge to engineer features that highlight differences between classes.\n   - **Class-Specific Training:**\n     - Train the model in a multi-stage fashion where initial stages focus on distinguishing between broadly different classes, and later stages fine-tune distinctions between similar classes.\n\n**YOUR IDEAS:**\n- Implement a confusion matrix-driven approach to iteratively improve the model by focusing on the most confused class pairs.\n- Use transfer learning by pre-training the model on a larger, similar dataset before fin ...
#    'optimization_results': {'analysis': {'error_patterns': ['Frequent misspellings of key terms',
#       'Inconsistent use of terminology',
#       'Lack of clarity in instructions'],
#      'root_causes': ['Inadequate training on template usage',
#       'Lack of standardized guidelines',
#       'Poor communication among team members']},
#     'recommendations': {'high_priority': ['Implement a standardized glossary of terms to ensure consistent terminology',
#       'Provide training sessions for all team members on the correct use of the template'],
#      'medium_priority': ['Introduce a spell-check and grammar-check tool within the template to reduce errors',
#       'Create a feedback loop where users can report issues with the template for continuous improvement'],
#      'low_priority': ['Regularly review and update the template based on user feedback and changing requirements',
#       'Encourage team members to share best practices and tips for using the template effectively']},
#     'improved_template': 'Updated template with standardized terminology, clear instructions, and integrated spell-check and grammar-check features.'},
#    'accuracy': 0.0}],
#  'accuracy_history': [0.5, 0.0, 0.0],
#  'final_accuracy': 0.0}

# %%
def run_feedback_loop(conversation_examples, ground_truths, iterations=3):
    current_prompt = sentiment_eval_prompt
    feedback_history = []
    accuracy_history = []
    
    for i in range(iterations):        
        print(f"\nIteration {i+1}")
        print("="*50)
        
        # Get model predictions and evaluate
        print("Current Prompt ######")
        print(current_prompt)
        predictions = evaluate_conversation(conversation_examples, current_prompt)
        eval_results = evaluate_with_ground_truth(predictions, ground_truths)
        
        # Track accuracy
        current_accuracy = eval_results["accuracy"]
        accuracy_history.append(current_accuracy)
        
        print(f"Accuracy: {current_accuracy*100:.2f}%")
        print(f"Correct: {eval_results['correct_predictions']}/{eval_results['total_predictions']}")
        
        # Show results for each conversation
        for idx, result in enumerate(eval_results["detailed_results"]):
            print(f"\nConversation {idx + 1}:")
            print(f"Predicted: {result['model_sentiment']}")
            print(f"Actual: {result['ground_truth_sentiment']}")
            print(f"Correct: {'✓' if result['is_correct'] else '✗'}")
        
        # Get optimization suggestions
        optimization_prompt = prepare_prompt(
            optimize_prompt,
            input_current_template=current_prompt,
            evaluation_results=json.dumps(eval_results, indent=2)
        )
        
            
        # Get optimization feedback
        optimization_response = bedrock_chat(optimization_prompt)
        optimization = json.loads(optimization_response)

        # Store feedback
        feedback_history.append({
            "iteration": i + 1,
            "current_prompt": current_prompt,
            "error_analysis": optimization["error_analysis"],
            "optimization_suggestions": optimization["optimization_suggestions"],
            "accuracy": current_accuracy
        })

        # Generate new instructions based on feedback history
        rewrite_prompt_formatted = prepare_prompt(
            rewrite_prompt,
            feedback_history=json.dumps(feedback_history, indent=2),
        )
        
        print("Optimization guidance ######")
        print(rewrite_prompt_formatted)

        new_instruction_response = bedrock_chat(rewrite_prompt_formatted)

        current_prompt =  json.loads(new_instruction_response)["new_template"]


    final_accuracy = accuracy_history[-1] if accuracy_history else 0
    
    return {
        "final_prompt": current_prompt,
        "feedback_history": feedback_history,
        "accuracy_history": accuracy_history,
        "final_accuracy": final_accuracy
    }
