# %%
conversation_example_1 = """
Customer: Hi, I ordered a laptop from your store last week, but I received the wrong color.

Agent: I apologize for this mistake. Could you please provide your order number?

Customer: Sure, it's #ORDER45678

Agent: Thank you. I can see the error in our system. I can arrange for a replacement in your preferred color, and we'll send you a prepaid return label for the current laptop. Also, I'll add a 10% discount on your next purchase as compensation for the inconvenience.

Customer: That's really great! Thank you so much for handling this so quickly. I appreciate the discount too!

Agent: You're welcome! The return label will be emailed to you within the next hour, and your replacement laptop will ship tomorrow with priority delivery.

Customer: Perfect! Have a great day! 
"""


conversation_example_2 = """
Customer: This is the third time I'm contacting you about my broken washing machine. No one has shown up for the repair despite scheduling 3 appointments!

Agent: I can see your previous contacts. Could you please provide your reference number again?

Customer: Are you kidding me? I've given that number THREE times already! It's WR789012. This is absolutely ridiculous.

Agent: I understand your frustration. Let me check the status.

Customer: I've been waiting for 20 minutes now. I'm paying for a premium warranty and this is the service I get? I want to speak to a supervisor immediately.

Agent: I apologize, but all our supervisors are currently unavailable. I can have one call you back within 24 hours.

Customer: This is unacceptable! I'm going to post about this terrible service on social media and file a formal complaint. You've wasted my time and money. I'll never buy from your company again.

Agent: I apologize for your experience. I'll escalate this case...

Customer: Don't bother. I'm done with this company. 
"""

# %%
sentiment_eval_prompt = """
Analyze the sentiment of the following conversation and classify it as either "positive" "negative" "neutral" or "mixed" 

Analyze the conversation below and provide the sentiment analysis in JSON format with two fields:
- sentiment: (positive/negative/neutral/mixed)
- reason: (detailed explanation for the classification)

<conversation>
{{conversation}}
</conversation>

Response:
{
    "sentiment": "",
    "reason": ""
}
"""

# %%
import boto3
import json

def bedrock_chat(prompt, model_id = "us.amazon.nova-pro-v1:0"):
    client = boto3.client("bedrock-runtime")

    system = [{"text": "You are a helpful assistant. Always respond with clean JSON format without markdown or escape characters."}]
    messages = [{"role": "user", "content": [{"text": prompt}]}]
    
    inf_params = {
        "maxTokens": 2048,
        "topP": 0.1,
        "temperature": 0.3
    }

    additionalModelRequestFields = {
        "inferenceConfig": {"topK": 20}
    }

    model_response = client.converse(
        modelId=model_id,
        messages=messages,
        system=system,
        inferenceConfig=inf_params,
        additionalModelRequestFields=additionalModelRequestFields
    )

    return model_response["output"]["message"]["content"][0]["text"]

def prepare_prompt(template, **kwargs):
    for key, value in kwargs.items():
        template = template.replace(f"{{{{{key}}}}}", value)
    return template

# %%
# Example usage
conversation_examples = [
    conversation_example_1,
    conversation_example_2
]

ground_truths = [
    {
        "sentiment": "positive",
    },
    {
        "sentiment": "negative",
    }
]

# %%
def evaluate_conversation(conversation_examples, current_prompt = sentiment_eval_prompt):
    results = []
    
    for conversation in conversation_examples:
        sentiment_prompt = prepare_prompt(current_prompt, conversation=conversation)
        sentiment_response = bedrock_chat(sentiment_prompt)
        
        try:
            result = json.loads(sentiment_response)
            results.append(result)
        except json.JSONDecodeError:
            results.append({
                "error": "Failed to parse API response",
                "sentiment_raw": sentiment_response
            })
    
    return results

# %%
evaluation_llm = evaluate_conversation(conversation_examples)

# %%
def evaluate_with_ground_truth(model_outputs, ground_truths):
    combined_results = []
    correct_predictions = 0
    total_predictions = len(ground_truths)
    
    for model_output, ground_truth in zip(model_outputs, ground_truths):
        sentiment_match = model_output.get("sentiment", "").lower() == ground_truth.get("sentiment", "").lower()
        if sentiment_match:
            correct_predictions += 1
        
        result = {
            "model_sentiment": model_output.get("sentiment", "").lower(),
            "model_reasoning": model_output.get("reason", ""),
            "ground_truth_sentiment": ground_truth.get("sentiment", "").lower(),
            "is_correct": sentiment_match
        }
        
        combined_results.append(result)
    
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    
    return {
        "accuracy": round(accuracy, 2),
        "correct_predictions": correct_predictions,
        "total_predictions": total_predictions,
        "detailed_results": combined_results
    }

# %%
evaluation_results = evaluate_with_ground_truth(evaluation_llm, ground_truths)

# %%
evaluation_results
# Out:
# {'accuracy': 1.0,
#  'correct_predictions': 2,
#  'total_predictions': 2,
#  'detailed_results': [{'model_sentiment': 'positive',
#    'model_reasoning': 'The conversation starts with a customer complaint about receiving the wrong color laptop. However, the agent responds promptly with an apology and offers a solution by arranging a replacement and providing a discount for the inconvenience. The customer expresses gratitude and appreciation for the quick resolution and added discount. The agent confirms the actions to be taken and ensures the customer that the issue will be resolved promptly. Overall, the interaction ends on a positive note with both parties satisfied.',
#    'ground_truth_sentiment': 'positive',
#    'is_correct': True},
#   {'model_sentiment': 'negative',
#    'model_reasoning': "The conversation is predominantly negative. The customer expresses strong dissatisfaction and frustration multiple times throughout the conversation. Key indicators include repeated complaints about the lack of repair service, the customer's anger at having to provide information multiple times, and their threats to post negative reviews and file a formal complaint. The customer's final statement indicates a complete loss of trust and intention to never buy from the company again. The agent's responses, while apologetic, do not mitigate the overall negative tone of the conversation.",
#    'ground_truth_sentiment': 'negative',
#    'is_correct': True}]}

# %%
optimize_prompt = """
Analyze the classification performance and provide optimization insights.

Current Template:
{{input_current_template}}

Evaluation Results:
{{evaluation_results}}

Provide a detailed analysis in this JSON format:
{
    "error_analysis": {
        "pattern_identification": {
            "strengths": ["List key patterns where sentiment classification was accurate"],
            "weaknesses": ["List patterns where misclassifications occurred"],
            "edge_cases": ["Identify challenging or ambiguous cases"]
        },
        "reasoning_assessment": {
            "logic_quality": "Evaluate the coherence and validity of reasoning",
            "consistency": "Assess classification consistency across similar cases",
            "confidence": "Analyze appropriateness of confidence levels"
        }
    },
    "optimization_suggestions": {
        "prompt_improvements": {
            "enhanced_template": "Proposed optimized prompt template",
            "key_changes": ["List specific modifications and their purpose"],
            "rationale": "Explanation of how changes address identified issues"
        },
        "classification_guidelines": ["Specific recommendations for improving classification accuracy"]
    }
}

"""

# %%
rewrite_prompt = """
Generate rewrite instructions based on historical feedback.

Feedback History:
{{feedback_history}}

DO FOLLOW CONVERSATION AND RESPONSE FORMAT AS FOLLOW

<conversation>
{{conversation}}
</conversation>

Response:
{
    "sentiment": "",
    "reason": ""
}

Provide a detailed new template in this JSON format:
{
    "new_template": write detailed optimized prompt here
}


"""

# %%
def run_feedback_loop(conversation_examples, ground_truths, iterations=3):
    current_prompt = sentiment_eval_prompt
    feedback_history = []
    accuracy_history = []
    
    for i in range(iterations):        
        print(f"\nIteration {i+1}")
        print("="*50)
        
        # Get model predictions and evaluate
        print("Current Prompt ######")
        print(current_prompt)
        predictions = evaluate_conversation(conversation_examples, current_prompt)
        eval_results = evaluate_with_ground_truth(predictions, ground_truths)
        
        # Track accuracy
        current_accuracy = eval_results["accuracy"]
        accuracy_history.append(current_accuracy)
        
        print(f"Accuracy: {current_accuracy*100:.2f}%")
        print(f"Correct: {eval_results['correct_predictions']}/{eval_results['total_predictions']}")
        
        # Show results for each conversation
        for idx, result in enumerate(eval_results["detailed_results"]):
            print(f"\nConversation {idx + 1}:")
            print(f"Predicted: {result['model_sentiment']}")
            print(f"Actual: {result['ground_truth_sentiment']}")
            print(f"Correct: {'✓' if result['is_correct'] else '✗'}")
        
        # Get optimization suggestions
        optimization_prompt = prepare_prompt(
            optimize_prompt,
            input_current_template=current_prompt,
            evaluation_results=json.dumps(eval_results, indent=2)
        )
        
            
        # Get optimization feedback
        optimization_response = bedrock_chat(optimization_prompt)
        optimization = json.loads(optimization_response)

        # Store feedback
        feedback_history.append({
            "iteration": i + 1,
            "current_prompt": current_prompt,
            "error_analysis": optimization["error_analysis"],
            "optimization_suggestions": optimization["optimization_suggestions"],
            "accuracy": current_accuracy
        })

        # Generate new instructions based on feedback history
        rewrite_prompt_formatted = prepare_prompt(
            rewrite_prompt,
            feedback_history=json.dumps(feedback_history, indent=2),
        )
        
        print("Optimization guidance ######")
        print(rewrite_prompt_formatted)

        new_instruction_response = bedrock_chat(rewrite_prompt_formatted)

        current_prompt =  json.loads(new_instruction_response)["new_template"]


    final_accuracy = accuracy_history[-1] if accuracy_history else 0
    
    return {
        "final_prompt": current_prompt,
        "feedback_history": feedback_history,
        "accuracy_history": accuracy_history,
        "final_accuracy": final_accuracy
    }

# %%
conversation_examples = [
    # Conversation 1: Sarcastic positive words but negative sentiment
    """
    Customer: Oh 'wonderful', another delayed delivery. Just 'perfect'!
    Agent: I apologize for the delay. I can check the status for you.
    Customer: That would be just 'fantastic', like the last three times I contacted support.
    Agent: I understand your frustration. Let me expedite this for you.
    Customer: Thanks SO much for your 'amazing' service! You're really 'exceptional' at this!
    """,
    
    # Conversation 2: Mixed signals with subtle final sentiment
    """
    Customer: My order arrived damaged, but your delivery was quick.
    Agent: I'm sorry about the damage. We'll send a replacement immediately.
    Customer: I appreciate the fast response, though this is the second time it happened.
    Agent: We'll add extra packaging protection and include a small gift for the inconvenience.
    Customer: Well, at least you're trying to improve. We'll see how it goes.
    """,
    
    # Conversation 3: Polite words masking negative sentiment
    """
    Customer: I hate to bother you, but this is my fourth attempt to resolve this issue.
    Agent: I'll be happy to help you today.
    Customer: Thank you, I know it's not your fault personally, but I've spent hours on this.
    Agent: I understand, let me review your case history.
    Customer: I appreciate your time, but I might need to explore other options if this continues.
    """,
    
    # Conversation 4: Complex emotional progression
    """
    Customer: This product is completely useless! I want a refund!
    Agent: I sincerely apologize. I can process your refund and offer a 30% discount on your next purchase.
    Customer: I don't want discounts, I've wasted enough money already!
    Agent: I understand. What if I send you our premium version as a replacement at no cost?
    Customer: Hmm... well, I've heard good things about that model. Fine, I'll give it a try.
    Agent: Excellent! I'll expedite that shipping for you.
    Customer: Thanks, I guess. But it better work this time.
    """
]

ground_truths = [
    {
        "sentiment": "negative"
    },
    {
        "sentiment": "neutral"
    },
    {
        "sentiment": "negative"
    },
    {
        "sentiment": "mixed"
    }
]

# %%
# Usage
results = run_feedback_loop(conversation_examples, ground_truths, iterations=3)
# Out:
# Iteration 1
# ==================================================
# Current Prompt ######
#
# Analyze the sentiment of the following conversation and classify it as either "positive" "negative" "neutral" or "mixed"
#
# Analyze the conversation below and provide the sentiment analysis in JSON format with two fields:
# - sentiment: (positive/negative/neutral/mixed)
# - reason: (detailed explanation for the classification)
#
# <conversation>
# {{conversation}}
# </conversation>
#
# Response:
# {
#     "sentiment": "",
#     "reason": ""
# }
#
# Accuracy: 50.00%
# Correct: 2/4
#
# Conversation 1:
# Predicted: negative
# Actual: negative
# Correct: ✓
#
# Conversation 2:
# Predicted: mixed
# Actual: neutral
# Correct: ✗
#
# Conversation 3:
# Predicted: mixed
# Actual: negative
# Correct: ✗
#
# Conversation 4:
# Predicted: mixed
# Actual: mixed
# Correct: ✓
# Optimization guidance ######
#
# Generate rewrite instructions based on historical feedback.
#
# Feedback History:
# [
#   {
#     "iteration": 1,
#     "current_prompt": "\nAnalyze the sentiment of the following conversation and classify it as either \"positive\" \"negative\" \"neutral\" or \"mixed\" \n\nAnalyze the conversation below and provide the sentiment analysis in JSON format with two fields:\n- sentiment: (positive/negative/neutral/mixed)\n- reason: (detailed explanation for the classification)\n\n<conversation>\n{{conversation}}\n</conversation>\n\nResponse:\n{\n    \"sentiment\": \"\",\n    \"reason\": \"\"\n}\n",
#     "error_analysis": {
#       "pattern_identification": {
#         "strengths": [
#           "Accurately identified strong negative sentiment with clear indicators of sarcasm and frustration.",
#           "Correctly classified mixed sentiment when both positive and negative elements were present."
#         ],
#         "weaknesses": [
#           "Misclassified a conversation as mixed when the ground truth was neutral, due to overemphasis on positive elements.",
#           "Misclassified a conversation as mixed when the ground truth was negative, failing to recognize the dominant negative sentiment."
#         ],
#         "edge_cases": [
#           "Conversations with both positive and negative elements but where one sentiment is more dominant.",
#           "Conversations with conditional acceptance or guarded positive remarks."
#         ]
#       },
#       "reasoning_assessment": {
#         "logic_quality": "The reasoning is generally coherent but tends to overemphasize positive elements in mixed or negative conversations.",
#         "consistency": "Inconsistent classification across similar cases, particularly in distinguishing between mixed and negative sentiments.",
#         "confidence": "Appropriate confidence levels in accurate classifications but lacks confidence in distinguishing nuanced sentiments."
#       }
#     },
#     "optimization_suggestions": {
#       "prompt_improvements": {
#         "enhanced_template": "Analyze the sentiment of the following conversation and classify it as either 'positive', 'negative', 'neutral', or 'mixed'. Provide a detailed explanation for the classification, emphasizing the dominant sentiment and considering the overall tone and context of the conversation.",
#         "key_changes": [
#           "Emphasize the need to identify the dominant sentiment in mixed conversations.",
#           "Instruct to consider the overall tone and context rather than individual positive or negative elements."
#         ],
#         "rationale": "These changes aim to improve the model's ability to distinguish between mixed and dominant sentiments by focusing on the overall conversation tone and context."
#       },
#       "classification_guidelines": [
#         "Provide clearer definitions and examples of 'mixed' and 'neutral' sentiments to reduce misclassification.",
#         "Encourage the model to weigh the intensity and frequency of sentiment indicators more heavily.",
#         "Implement a review mechanism for edge cases to ensure consistent application of classification criteria."
#       ]
#     },
#     "accuracy": 0.5
#   }
# ]
#
# DO FOLLOW CONVERSATION AND RESPONSE FORMAT AS FOLLOW
#
# <conversation>
# {{conversation}}
# </conversation>
#
# Response:
# {
#     "sentiment": "",
#     "reason": ""
# }
#
# Provide a detailed new template in this JSON format:
# {
#     "new_template": write detailed optimized prompt here
# }
# ---------------------------------------------------------------------------
# ThrottlingException                       Traceback (most recent call last)
# Cell In[151], line 2
#       1 # Usage
# ----> 2 results = run_feedback_loop(conversation_examples, ground_truths, iterations=3)
#
# Cell In[149], line 60, in run_feedback_loop(conversation_examples, ground_truths, iterations)
#      57     print("Optimization guidance ######")
#      58     print(rewrite_prompt_formatted)
# ---> 60     new_instruction_response = bedrock_chat(rewrite_prompt_formatted)
#      62     current_prompt =  json.loads(new_instruction_response)["new_template"]
#      65 final_accuracy = accuracy_history[-1] if accuracy_history else 0
#
# Cell In[140], line 20, in bedrock_chat(prompt, model_id)
#      10 inf_params = {
#      11     "maxTokens": 2048,
#      12     "topP": 0.1,
#      13     "temperature": 0.3
#      14 }
#      16 additionalModelRequestFields = {
#      17     "inferenceConfig": {"topK": 20}
#      18 }
# ---> 20 model_response = client.converse(
#      21     modelId=model_id,
#      22     messages=messages,
#      23     system=system,
#      24     inferenceConfig=inf_params,
#      25     additionalModelRequestFields=additionalModelRequestFields
#      26 )
#      28 return model_response["output"]["message"]["content"][0]["text"]
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/botocore/client.py:569, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     565     raise TypeError(
#     566         f"{py_operation_name}() only accepts keyword arguments."
#     567     )
#     568 # The "self" in this scope is referring to the BaseClient.
# --> 569 return self._make_api_call(operation_name, kwargs)
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/botocore/client.py:1023, in BaseClient._make_api_call(self, operation_name, api_params)
#    1019     error_code = error_info.get("QueryErrorCode") or error_info.get(
#    1020         "Code"
#    1021     )
#    1022     error_class = self.exceptions.from_code(error_code)
# -> 1023     raise error_class(parsed_response, operation_name)
#    1024 else:
#    1025     return parsed_response
#
# ThrottlingException: An error occurred (ThrottlingException) when calling the Converse operation (reached max retries: 4): Too many requests, please wait before trying again.

# %%
results
# Out:
# {'final_prompt': 'Analyze the sentiment of the following conversation and classify it as either \'positive\', \'negative\', \'neutral\', or \'mixed\'. Consider the overall tone, specific keywords, and the balance of positive and negative elements. Pay special attention to sarcasm, irony, and the context of positive and negative remarks. Provide a detailed explanation for the classification, including specific phrases and their impact on the sentiment.\n\nAnalyze the conversation below and provide the sentiment analysis in JSON format with two fields:\n- sentiment: (positive/negative/neutral/mixed)\n- reason: (detailed explanation for the classification)\n\n<conversation>\n{{conversation}}\n</conversation>\n\nResponse:\n{\n    "sentiment": "",\n    "reason": ""\n}',
#  'feedback_history': [{'iteration': 1,
#    'current_prompt': '\nAnalyze the sentiment of the following conversation and classify it as either "positive" "negative" "neutral" or "mixed" \n\nAnalyze the conversation below and provide the sentiment analysis in JSON format with two fields:\n- sentiment: (positive/negative/neutral/mixed)\n- reason: (detailed explanation for the classification)\n\n<conversation>\n{{conversation}}\n</conversation>\n\nResponse:\n{\n    "sentiment": "",\n    "reason": ""\n}\n',
#    'error_analysis': {'pattern_identification': {'strengths': ['Accurate classification of neutral sentiment when both positive and negative elements are balanced.'],
#      'weaknesses': ['Misclassification of negative sentiment as neutral when the conversation contains significant negative elements.',
#       'Misclassification of mixed sentiment as neutral when the conversation contains sarcasm and frustration.'],
#      'edge_cases': ['Conversations with sarcasm and mixed emotions are challenging to classify accurately.',
#       'Conversations with a high volume of negative feedback are difficult to balance with positive agent responses.']},
#     'reasoning_assessment': {'logic_quality': 'The reasoning provided for each classification is generally coherent and valid, but there is room for improvement in identifying dominant sentiments.',
#      'consistency': 'The model shows inconsistency in classifying similar cases, particularly when negative sentiments are present.',
#      'confidence': 'The confidence levels assigned to classifications do not always align with the accuracy of the sentiment classification.'}},
#    'optimization_suggestions': {'prompt_improvements': {'enhanced_template': "Analyze the sentiment of the following conversation and classify it as either 'positive', 'negative', 'neutral', or 'mixed'. Consider the overall tone, specific keywords, and the balance of positive and negative elements. Provide a detailed explanation for the classification.",
#      'key_changes': ['Added emphasis on considering the overall tone and specific keywords.',
#       'Clarified the need to balance positive and negative elements in the classification.'],
#      'rationale': 'These changes aim to guide the model to focus more on the dominant sentiment and specific indicators within the conversation, improving classification accuracy.'},
#     'classification_guidelines': ['Prioritize identifying the dominant sentiment in the conversation, especially when mixed sentiments are present.',
#      'Pay attention to specific keywords and phrases that indicate strong positive or negative emotions.',
#      'Ensure consistency in classifying similar conversations by using a standardized approach to evaluate the balance of sentiments.']},
#    'accuracy': 0.5},
#   {'iteration': 2,
#    'current_prompt': 'Analyze the sentiment of the following conversation and classify it as either \'positive\', \'negative\', \'neutral\', or \'mixed\'. Consider the overall tone, specific keywords, and the balance of positive and negative elements. Provide a detailed explanation for the classification.\n\nAnalyze the conversation below and provide the sentiment analysis in JSON format with two fields:\n- sentiment: (positive/negative/neutral/mixed)\n- reason: (detailed explanation for the classification)\n\n<conversation>\n{{conversation}}\n</conversation>\n\nResponse:\n{\n    "sentiment": "",\n    "reason": ""\n}\n',
#    'error_analysis': {'pattern_identification': {'strengths': ['Accurate classification of neutral sentiment when both positive and negative elements are balanced',
#       'Correct identification of mixed sentiment when both positive and negative elements are present in the conversation'],
#      'weaknesses': ['Misclassification of mixed sentiment as neutral when sarcasm and negative elements are present',
#       'Misclassification of neutral sentiment as negative when positive elements are overshadowed by negative elements'],
#      'edge_cases': ['Conversations with high sarcasm or irony that are difficult to classify accurately',
#       'Conversations with mixed sentiments where the balance between positive and negative elements is subtle']},
#     'reasoning_assessment': {'logic_quality': 'The reasoning provided for each classification is generally coherent and valid, but there are instances where the balance of positive and negative elements is not accurately assessed.',
#      'consistency': 'The classification consistency across similar cases is moderate. The model sometimes fails to consistently classify similar conversations with the same sentiment.',
#      'confidence': 'The confidence levels in the classifications are not always appropriate, especially in cases where the sentiment is mixed or neutral.'}},
#    'optimization_suggestions': {'prompt_improvements': {'enhanced_template': 'Analyze the sentiment of the following conversation and classify it as either \'positive\', \'negative\', \'neutral\', or \'mixed\'. Consider the overall tone, specific keywords, and the balance of positive and negative elements. Provide a detailed explanation for the classification. Pay special attention to sarcasm, irony, and the context of positive and negative remarks.\n\nAnalyze the conversation below and provide the sentiment analysis in JSON format with two fields:\n- sentiment: (positive/negative/neutral/mixed)\n- reason: (detailed explanation for the classification)\n\n<conversation>\n{{conversation}}\n</conversation>\n\nResponse:\n{\n    "sentiment": "",\n    "reason": ""\n}',
#      'key_changes': ['Added a note to pay special attention to sarcasm, irony, and the context of positive and negative remarks.',
#       'Clarified the need to consider the balance of positive and negative elements in the conversation.'],
#      'rationale': 'These changes address the issues of misclassification by providing clearer guidelines on how to assess sarcasm, irony, and the balance of positive and negative elements.'},
#     'classification_guidelines': ['Ensure that sarcasm and irony are accurately identified and considered in the sentiment classification.',
#      'Pay attention to the context of positive and negative remarks to avoid misclassification.',
#      'Use a more nuanced approach to assess the balance of positive and negative elements in the conversation.']},
#    'accuracy': 0.5},
#   {'iteration': 3,
#    'current_prompt': 'Analyze the sentiment of the following conversation and classify it as either \'positive\', \'negative\', \'neutral\', or \'mixed\'. Consider the overall tone, specific keywords, and the balance of positive and negative elements. Provide a detailed explanation for the classification. Pay special attention to sarcasm, irony, and the context of positive and negative remarks.\n\nAnalyze the conversation below and provide the sentiment analysis in JSON format with two fields:\n- sentiment: (positive/negative/neutral/mixed)\n- reason: (detailed explanation for the classification)\n\n<conversation>\n{{conversation}}\n</conversation>\n\nResponse:\n{\n    "sentiment": "",\n    "reason": ""\n}',
#    'error_analysis': {'pattern_identification': {'strengths': ['Accurate identification of sarcasm and irony in negative sentiment conversations',
#       'Balanced assessment of mixed sentiment conversations'],
#      'weaknesses': ["Misclassification of a conversation with balanced positive and negative elements as 'neutral' instead of 'negative'",
#       'Inconsistent reasoning for mixed sentiment classification'],
#      'edge_cases': ['Conversations with subtle sarcasm or irony that are not easily detected',
#       'Conversations with a mix of positive and negative elements that are not clearly balanced']},
#     'reasoning_assessment': {'logic_quality': 'The reasoning provided is generally coherent and valid, but there are instances where the reasoning does not fully align with the sentiment classification.',
#      'consistency': "The classification consistency is moderate. The model accurately classifies similar conversations with sarcasm and irony as 'negative', but it fails to consistently classify balanced conversations as 'neutral' or 'mixed'.",
#      'confidence': "The confidence levels are generally appropriate, but there is room for improvement in distinguishing between 'neutral' and 'mixed' sentiments."}},
#    'optimization_suggestions': {'prompt_improvements': {'enhanced_template': "Analyze the sentiment of the following conversation and classify it as either 'positive', 'negative', 'neutral', or 'mixed'. Consider the overall tone, specific keywords, and the balance of positive and negative elements. Pay special attention to sarcasm, irony, and the context of positive and negative remarks. Provide a detailed explanation for the classification, including specific phrases and their impact on the sentiment.",
#      'key_changes': ['Added emphasis on paying attention to sarcasm, irony, and context',
#       'Specified the need for a detailed explanation including specific phrases and their impact'],
#      'rationale': 'These changes will help the model better identify and weigh the impact of sarcasm, irony, and context, leading to more accurate sentiment classifications.'},
#     'classification_guidelines': ["Develop a more nuanced understanding of the balance between positive and negative elements to better distinguish between 'neutral' and 'mixed' sentiments.",
#      'Incorporate additional training on edge cases, such as conversations with subtle sarcasm or irony.',
#      'Ensure consistency in reasoning by providing clear guidelines for classifying balanced conversations.']},
#    'accuracy': 0.75}],
#  'accuracy_history': [0.5, 0.5, 0.75],
#  'final_accuracy': 0.75}
